# %% [markdown]
# ### CoinMarketCap Study
# - API documentation is enable to be read in https://coinmarketcap.com/api/documentation/v1/#

# %% [markdown]
# ### Health-Check

# %%
import requests as r
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import os
import pandas as pd

# %% [markdown]
# - Testing the API connection in the sandbox environment

# %%
test_url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'b54bcf4d-1bca-4e8e-9a24-22ff2c3d462c',
}

session = r.Session()
session.headers.update(headers)

try:
  response = session.get(test_url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-12-27T21:44:58.519Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 9939, 'name': 'jksqb4fkrbg', 'symbol': 'dqm2ltyiq8c', 'slug': 'jidjcw78a1', 'cmc_rank': 3005, 'num_market_pairs': 731, 'circulating_supply': 4532, 'total_supply': 3382, 'max_supply': 4373, 'infinite_supply': None, 'last_updated': '2024-12-27T21:44:58.519Z', 'date_added': '2024-12-27T21:44:58.519Z', 'tags': ['ppxh64jcjs', '4r9mxvsv1co', 'awqm8yvu6sn', 'qhvm2n4hdd', 'h4rrgi09sxl', 'xwzregnh7h', 'sl6y1x9v72', 'pmng6b1ndu', 'ffs0eqzvt3a', '1mfiz1a0hjn'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.660685993441257, 'volume_24h': 3208, 'volume_change_24h': 0.5902902391452838, 'percent_change_1h': 0.3773920115147491, 'percent_change_24h': 0.43601007392795643, 'percent_change_7d': 0.2916652594641933, 'market_cap': 0.5681027804468033, 'market_cap_dominance': 4606, 'fully_diluted_market_cap': 0.2604798852245356, 'last_updated': '2024-12-27T21:44:58.519Z'}}}, {'id': 2235, 'name': '08r55qill6fr', 'symbol': '9ix7yfajif', 'slug': '9ok4wk67ge8', 'cmc_rank': 1591, 'num_market_pairs': 5662, 'circulating_supply': 1999, 'total_supply': 7335, 'max_supply': 4198, 'infinite_supply': None, 'last_updated': '2024-12-27T21:44:58.519Z', 'date_added': '2024-12-27T21:44:58.519Z', 'tags': ['bt3iohat0qi', '45orfjralsk', 'sbu3ffod2ul', '0w1dlg8xbyn', '6yk7ngcsdx2', '6k5jm2gkihx', 'o4ojimtetl8', 'qlfvrgn2dl', 'mcg0l45kqen', '3lzg8xe46gi'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.20211740814498325, 'volume_24h': 8565, 'volume_change_24h': 0.2575090718799342, 'percent_change_1h': 0.4234261469874532, 'percent_change_24h': 0.6621461529498831, 'percent_change_7d': 0.4559120765498743, 'market_cap': 0.49825675912394485, 'market_cap_dominance': 272, 'fully_diluted_market_cap': 0.414878615784529, 'last_updated': '2024-12-27T21:44:58.519Z'}}}, {'id': 6907, 'name': 'jp3r6g3nqoi', 'symbol': 'adse2hbwy7i', 'slug': 'vnnehjzy3', 'cmc_rank': 4408, 'num_market_pairs': 4677, 'circulating_supply': 3856, 'total_supply': 5707, 'max_supply': 3668, 'infinite_supply': None, 'last_updated': '2024-12-27T21:44:58.519Z', 'date_added': '2024-12-27T21:44:58.519Z', 'tags': ['ezdmr5odfpv', 'igbsenr6f8', 'qk8a7r38zk', 'p4t13asbno', 'dpqbzlda0yi', 'av3ueysr1xs', '59tbv58dk2x', '67krgmbml4c', 'lpgnsufhjw', '1awrpweu69zh'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.6699829365179655, 'volume_24h': 107, 'volume_change_24h': 0.5076016377447699, 'percent_change_1h': 0.7171063086188962, 'percent_change_24h': 0.05824716309769906, 'percent_change_7d': 0.22090059609334323, 'market_cap': 0.5324926069966727, 'market_cap_dominance': 9704, 'fully_diluted_market_cap': 0.08651046735362677, 'last_updated': '2024-12-27T21:44:58.519Z'}}}, {'id': 8224, 'name': 'gj7h5unw7xv', 'symbol': 'z7rvexd07n', 'slug': 'gwwcu6ajvy', 'cmc_rank': 8038, 'num_market_pairs': 3651, 'circulating_supply': 6881, 'total_supply': 391, 'max_supply': 1409, 'infinite_supply': None, 'last_updated': '2024-12-27T21:44:58.519Z', 'date_added': '2024-12-27T21:44:58.519Z', 'tags': ['7trpagjhitj', 'mhuuat2vqzm', 'nlbvwh90kg', 'bud4ba5sx59', '64vsfubvqmj', '8pfwm9w9wox', '368qsjelt9z', 'do1vpddo8y', 'c1saaxcvu4t', 'ezk6yqn044m'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.5859114726872587, 'volume_24h': 2535, 'volume_change_24h': 0.818891289055349, 'percent_change_1h': 0.11712450381649098, 'percent_change_24h': 0.9832214377475119, 'percent_change_7d': 0.5796777541582439, 'market_cap': 0.7757483316943454, 'market_cap_dominance': 6933, 'fully_diluted_market_cap': 0.875042747667794, 'last_updated': '2024-12-27T21:44:58.519Z'}}}, {'id': 4484, 'name': '0y9bovbdcwl', 'symbol': 'zb ...

# %% [markdown]
# - Testing the API connection in production environment with my own user credentials

# %%
# defining the base url that will be useful on any later calls
base_url= os.environ.get('COIN_MARKET_API_BASE_URL')

# defining the access_token regarding my own user in the subscribed platform
access_token= os.environ.get('COIN_MARKET_API_ACCESS_TOKEN')

# api call parameters (here using the same as above)
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}

# redefining the headers variable according to documentation reference, but with the appropriate pointer to my user access token
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': access_token,
}

# doing the api call attempt
test_url= base_url+'/v1/cryptocurrency/listings/latest'
try:
    response = r.get(test_url, params= parameters, headers= headers)
    data= json.loads(response.text)
    #print(data) 
    print(response.status_code)
    print(response.reason)
except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)
# Out:
# 200
# OK

# %%
data
# Out:
# {'status': {'timestamp': '2024-12-27T21:45:23.228Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 81,
#   'credit_count': 25,
#   'notice': None,
#   'total_count': 10483},
#  'data': [{'id': 1,
#    'name': 'Bitcoin',
#    'symbol': 'BTC',
#    'slug': 'bitcoin',
#    'num_market_pairs': 11853,
#    'date_added': '2010-07-13T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'sha-256',
#     'store-of-value',
#     'state-channel',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'binance-labs-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'dcg-portfolio',
#     'dragonfly-capital-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'framework-ventures-portfolio',
#     'galaxy-digital-portfolio',
#     'huobi-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     '1confirmation-portfolio',
#     'winklevoss-capital-portfolio',
#     'usv-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'multicoin-capital-portfolio',
#     'paradigm-portfolio',
#     'bitcoin-ecosystem',
#     'ftx-bankruptcy-estate',
#     '2017-2018-alt-season'],
#    'max_supply': 21000000,
#    'circulating_supply': 19802034,
#    'total_supply': 19802034,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 1,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:43:00.000Z',
#    'quote': {'USD': {'price': 94405.66421955825,
#      'volume_24h': 52247510198.15572,
#      'volume_change_24h': 10.2826,
#      'percent_change_1h': 0.01313664,
#      'percent_change_24h': -1.25146815,
#      'percent_change_7d': -2.05214152,
#      'percent_change_30d': -2.09779044,
#      'percent_change_60d': 35.43545214,
#      'percent_change_90d': 43.73933907,
#      'market_cap': 1869424172668.2761,
#      'market_cap_dominance': 56.7571,
#      'fully_diluted_market_cap': 1982518948610.72,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:43:00.000Z'}}},
#   {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'num_market_pairs': 9737,
#    'date_added': '2015-08-07T00:00:00.000Z',
#    'tags': ['pos',
#     'smart-contracts',
#     'ethereum-ecosystem',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'binance-labs-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'dcg-portfolio',
#     'dragonfly-capital-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'framework-ventures-portfolio',
#     'hashkey-capital-portfolio',
#     'kenetic-capital-portfolio',
#     'huobi-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     '1confirmation-portfolio',
#     'winklevoss-capital-portfolio',
#     'usv-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'multicoin-capital-portfolio',
#     'paradigm-portfolio',
#     'layer-1',
#     'ftx-bankruptcy-estate'],
#    'max_supply': None,
#    'circulating_supply': 120464488.60231528,
#    'total_supply': 120464488.60231528,
#    'infinite_supply': True,
#    'platform': None,
#    'cmc_rank': 2,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:43:00.000Z',
#    'quote': {'USD': {'price': 3321.1983079213787,
#      'volume_24h': 24582003646.26738,
#      'volume_change_24h': 13.7552,
#      'percent_change_1h': -0.53465256,
#      'percent_change_24h': -0.12062212,
#      'percent_change_7d': -3.0589863,
#      'percent_change_30d': -8.6450004,
#      'percent_change_60d': 30.66220623,
#      'percent_change_90d': 24.43268022,
#      'market_cap': 400086455710.6237,
#      'market_cap_dominance': 12.1442,
#      'fully_diluted_market_cap': 400086455710.62,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:43:00.000Z'}}},
#   {'id': 825,
#    'name': 'Tether USDt',
#    'symbol': 'USDT',
#    'slug': 'tether',
#    'num_market_pairs': 110299,
#    'date_added': '2015-02-25T00:00:00.000Z',
#    'tags': ['stablecoin',
#     'asset-backed-stablecoin',
#     'avalanche-ecosystem',
#     'solana-ecosystem',
#     'arbitrum-ecosytem',
#     'moonriver-ecosystem',
#     'injective-ecosystem',
#     'bnb-chain',
#     'usd-stablecoin',
#     'optimism-ecosystem',
#     'fiat-stablecoin'],
#    'max_supply': None,
#    'circulating_supply': 139440581307.0706,
#    'total_supply': 143440125282.73163,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xdac17f958d2ee523a2206206994597c13d831ec7'},
#    'infinite_supply': True,
#    'cmc_rank': 3,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 0.9986708464259877,
#      'volume_24h': 109698714406.6929,
#      'volume_change_24h': 5.0679,
#      'percent_change_1h': 0.00624725,
#      'percent_change_24h': -0.02124433,
#      'percent_change_7d': -0.09487433,
#      'percent_change_30d': -0.25243848,
#      'percent_change_60d': -0.1203282,
#      'percent_change_90d': -0.14813571,
#      'market_cap': 139255243360.06393,
#      'market_cap_dominance': 4.2376,
#      'fully_diluted_market_cap': 143249471327.56,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 52,
#    'name': 'XRP',
#    'symbol': 'XRP',
#    'slug': 'xrp',
#    'num_market_pairs': 1490,
#    'date_added': '2013-08-04T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'enterprise-solutions',
#     'arrington-xrp-capital-portfolio',
#     'galaxy-digital-portfolio',
#     'a16z-portfolio',
#     'pantera-capital-portfolio',
#     'ftx-bankruptcy-estate',
#     '2017-2018-alt-season'],
#    'max_supply': 100000000000,
#    'circulating_supply': 57410227039,
#    'total_supply': 99986740020,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 4,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:43:00.000Z',
#    'quote': {'USD': {'price': 2.1521791135338915,
#      'volume_24h': 5462128387.895428,
#      'volume_change_24h': 1.4334,
#      'percent_change_1h': -0.77930294,
#      'percent_change_24h': -0.04745341,
#      'percent_change_7d': -3.5685587,
#      'percent_change_30d': 43.88997682,
#      'percent_change_60d': 315.35239733,
#      'percent_change_90d': 249.45855768,
#      'market_cap': 123557091536.57446,
#      'market_cap_dominance': 3.7504,
#      'fully_diluted_market_cap': 215217911353.39,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:43:00.000Z'}}},
#   {'id': 1839,
#    'name': 'BNB',
#    'symbol': 'BNB',
#    'slug': 'bnb',
#    'num_market_pairs': 2318,
#    'date_added': '2017-07-25T00:00:00.000Z',
#    'tags': ['marketplace',
#     'centralized-exchange',
#     'payments',
#     'smart-contracts',
#     'alameda-research-portfolio',
#     'multicoin-capital-portfolio',
#     'bnb-chain',
#     'layer-1',
#     'alleged-sec-securities',
#     'celsius-bankruptcy-estate'],
#    'max_supply': None,
#    'circulating_supply': 144007285.93,
#    'total_supply': 144007285.93,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 5,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:43:00.000Z',
#    'quote': {'USD': {'price': 691.1537908258586,
#      'volume_24h': 1904541997.3190215,
#      'volume_change_24h': 53.7009,
#      'percent_change_1h': -0.20603583,
#      'percent_change_24h': 0.24199605,
#      'percent_change_7d': 3.20643077,
#      'percent_change_30d': 7.80273873,
#      'percent_change_60d': 14.92294705,
#      'percent_change_90d': 15.39525944,
#      'market_cap': 99531181577.06282,
#      'market_cap_dominance': 3.0218,
#      'fully_diluted_market_cap': 99531181577.06,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:43:00.000Z'}}},
#   {'id': 5426,
#    'name': 'Solana',
#    'symbol': 'SOL',
#    'slug': 'solana',
#    'num_market_pairs': 816,
#    'date_added': '2020-04-10T00:00:00.000Z',
#    'tags': ['pos',
#     'platform',
#     'solana-ecosystem',
#     'cms-holdings-portfolio',
#     'kenetic-capital-portfolio',
#     'alameda-research-portfolio',
#     'multicoin-capital-portfolio',
#     'okx-ventures-portfolio',
#     'layer-1',
#     'ftx-bankruptcy-estate',
#     'alleged-sec-securities',
#     'cmc-crypto-awards-2024'],
#    'max_supply': None,
#    'circulating_supply': 479649397.9793466,
#    'total_supply': 591075233.110292,
#    'infinite_supply': True,
#    'platform': None,
#    'cmc_rank': 6,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 185.22682971036377,
#      'volume_24h': 2776640072.3050094,
#      'volume_change_24h': -2.6675,
#      'percent_change_1h': -0.41891917,
#      'percent_change_24h': -2.01580807,
#      'percent_change_7d': -2.22684937,
#      'percent_change_30d': -23.00058001,
#      'percent_change_60d': 4.3783977,
#      'percent_change_90d': 18.35303918,
#      'market_cap': 88843937360.19893,
#      'market_cap_dominance': 2.7169,
#      'fully_diluted_market_cap': 109482991549.33,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 74,
#    'name': 'Dogecoin',
#    'symbol': 'DOGE',
#    'slug': 'dogecoin',
#    'num_market_pairs': 1135,
#    'date_added': '2013-12-15T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'scrypt',
#     'medium-of-exchange',
#     'memes',
#     'payments',
#     'doggone-doggerel',
#     'bnb-chain',
#     'ftx-bankruptcy-estate'],
#    'max_supply': None,
#    'circulating_supply': 147379436383.70523,
#    'total_supply': 147379436383.70523,
#    'infinite_supply': True,
#    'platform': None,
#    'cmc_rank': 7,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:43:00.000Z',
#    'quote': {'USD': {'price': 0.3121626350256909,
#      'volume_24h': 2168970399.621177,
#      'volume_change_24h': -14.5752,
#      'percent_change_1h': -0.57581178,
#      'percent_change_24h': -0.02660106,
#      'percent_change_7d': 1.17933513,
#      'percent_change_30d': -22.38432244,
#      'percent_change_60d': 96.29672334,
#      'percent_change_90d': 141.23351221,
#      'market_cap': 46006353210.13861,
#      'market_cap_dominance': 1.4,
#      'fully_diluted_market_cap': 46006353210.14,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:43:00.000Z'}}},
#   {'id': 3408,
#    'name': 'USDC',
#    'symbol': 'USDC',
#    'slug': 'usd-coin',
#    'num_market_pairs': 24197,
#    'date_added': '2018-10-08T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'stablecoin',
#     'asset-backed-stablecoin',
#     'coinbase-ventures-portfolio',
#     'solana-ecosystem',
#     'hedera-hashgraph-ecosystem',
#     'arbitrum-ecosytem',
#     'moonriver-ecosystem',
#     'bnb-chain',
#     'usd-stablecoin',
#     'optimism-ecosystem',
#     'base-ecosystem',
#     'fiat-stablecoin'],
#    'max_supply': None,
#    'circulating_supply': 43537484885.114655,
#    'total_supply': 43537484885.114655,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#    'infinite_supply': False,
#    'cmc_rank': 8,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 1.0000657521251983,
#      'volume_24h': 7076564661.375099,
#      'volume_change_24h': 13.4323,
#      'percent_change_1h': 0.00786723,
#      'percent_change_24h': 0.01523766,
#      'percent_change_7d': 6.449e-05,
#      'percent_change_30d': 0.02117621,
#      'percent_change_60d': -0.00530827,
#      'percent_change_90d': 0.01800504,
#      'market_cap': 43540347567.271645,
#      'market_cap_dominance': 1.3315,
#      'fully_diluted_market_cap': 43540347567.27,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 2010,
#    'name': 'Cardano',
#    'symbol': 'ADA',
#    'slug': 'cardano',
#    'num_market_pairs': 1421,
#    'date_added': '2017-10-01T00:00:00.000Z',
#    'tags': ['dpos',
#     'pos',
#     'platform',
#     'research',
#     'smart-contracts',
#     'staking',
#     'cardano-ecosystem',
#     'cardano',
#     'layer-1',
#     'alleged-sec-securities',
#     '2017-2018-alt-season'],
#    'max_supply': 45000000000,
#    'circulating_supply': 35131891445.17966,
#    'total_supply': 44995113979.40014,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 9,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:42:00.000Z',
#    'quote': {'USD': {'price': 0.8831755399266017,
#      'volume_24h': 888490469.5136043,
#      'volume_change_24h': 15.1545,
#      'percent_change_1h': -0.62158577,
#      'percent_change_24h': 2.91794958,
#      'percent_change_7d': -3.01808661,
#      'percent_change_30d': -12.90419613,
#      'percent_change_60d': 156.48078776,
#      'percent_change_90d': 121.23565769,
#      'market_cap': 31027627195.739304,
#      'market_cap_dominance': 0.942,
#      'fully_diluted_market_cap': 39742899296.7,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:42:00.000Z'}}},
#   {'id': 1958,
#    'name': 'TRON',
#    'symbol': 'TRX',
#    'slug': 'tron',
#    'num_market_pairs': 1089,
#    'date_added': '2017-09-13T00:00:00.000Z',
#    'tags': ['media',
#     'payments',
#     'tron-ecosystem',
#     'layer-1',
#     'dwf-labs-portfolio',
#     'alleged-sec-securities',
#     '2017-2018-alt-season'],
#    'max_supply': None,
#    'circulating_supply': 86203452587.87383,
#    'total_supply': 86203453788.44757,
#    'infinite_supply': True,
#    'platform': None,
#    'cmc_rank': 10,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:43:00.000Z',
#    'quote': {'USD': {'price': 0.25975449007341517,
#      'volume_24h': 1302753624.8347876,
#      'volume_change_24h': 44.736,
#      'percent_change_1h': -0.04452189,
#      'percent_change_24h': 3.03918781,
#      'percent_change_7d': 5.88736725,
#      'percent_change_30d': 29.10566896,
#      'percent_change_60d': 58.29439812,
#      'percent_change_90d': 68.06773014,
#      'market_cap': 22391733869.530987,
#      'market_cap_dominance': 0.6798,
#      'fully_diluted_market_cap': 22391734181.39,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:43:00.000Z'}}},
#   {'id': 5805,
#    'name': 'Avalanche',
#    'symbol': 'AVAX',
#    'slug': 'avalanche',
#    'num_market_pairs': 829,
#    'date_added': '2020-07-13T00:00:00.000Z',
#    'tags': ['defi',
#     'smart-contracts',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'avalanche-ecosystem',
#     'cms-holdings-portfolio',
#     'dragonfly-capital-portfolio',
#     'real-world-assets',
#     'layer-1'],
#    'max_supply': 715748719,
#    'circulating_supply': 409863292.0110723,
#    'total_supply': 448199592.0110723,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 11,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 36.83904836278273,
#      'volume_24h': 476640708.0885893,
#      'volume_change_24h': -3.995,
#      'percent_change_1h': -0.35559481,
#      'percent_change_24h': -1.45358305,
#      'percent_change_7d': -4.16815419,
#      'percent_change_30d': -15.22160129,
#      'percent_change_60d': 41.17548147,
#      'percent_change_90d': 25.75977389,
#      'market_cap': 15098973636.52523,
#      'market_cap_dominance': 0.4617,
#      'fully_diluted_market_cap': 26367501674.84,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 11419,
#    'name': 'Toncoin',
#    'symbol': 'TON',
#    'slug': 'toncoin',
#    'num_market_pairs': 644,
#    'date_added': '2021-08-26T13:40:22.000Z',
#    'tags': ['pos',
#     'layer-1',
#     'ftx-bankruptcy-estate',
#     'dwf-labs-portfolio',
#     'toncoin-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 2552352944.9165154,
#    'total_supply': 5118418696.282256,
#    'infinite_supply': True,
#    'platform': None,
#    'cmc_rank': 12,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 5.740050737230206,
#      'volume_24h': 211779342.43191117,
#      'volume_change_24h': 1.3811,
#      'percent_change_1h': -1.53655601,
#      'percent_change_24h': 0.01239564,
#      'percent_change_7d': 6.79673719,
#      'percent_change_30d': -9.72462339,
#      'percent_change_60d': 14.25834172,
#      'percent_change_90d': -2.04235941,
#      'market_cap': 14650635403.13973,
#      'market_cap_dominance': 0.4481,
#      'fully_diluted_market_cap': 29379983011.05,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 1975,
#    'name': 'Chainlink',
#    'symbol': 'LINK',
#    'slug': 'chainlink',
#    'num_market_pairs': 1907,
#    'date_added': '2017-09-20T00:00:00.000Z',
#    'tags': ['platform',
#     'defi',
#     'oracles',
#     'smart-contracts',
#     'substrate',
#     'polkadot',
#     'avalanche-ecosystem',
#     'solana-ecosystem',
#     'framework-ventures-portfolio',
#     'polygon-ecosystem',
#     'fantom-ecosystem',
#     'cardano-ecosystem',
#     'web3',
#     'near-protocol-ecosystem',
#     'arbitrum-ecosytem',
#     'cardano',
#     'injective-ecosystem',
#     'optimism-ecosystem',
#     'real-world-assets',
#     'celsius-bankruptcy-estate'],
#    'max_supply': None,
#    'circulating_supply': 638099970.4527867,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x514910771af9ca656af840dff83e8264ecf986ca'},
#    'infinite_supply': False,
#    'cmc_rank': 13,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:43:00.000Z',
#    'quote': {'USD': {'price': 21.859015129598088,
#      'volume_24h': 760622702.1526003,
#      'volume_change_24h': -0.3869,
#      'percent_change_1h': -0.86373059,
#      'percent_change_24h': -3.52288458,
#      'percent_change_7d': -4.30197635,
#      'percent_change_30d': 19.38407988,
#      'percent_change_60d': 97.02853093,
#      'percent_change_90d': 70.67270395,
#      'market_cap': 13948236908.323557,
#      'market_cap_dominance': 0.4264,
#      'fully_diluted_market_cap': 21859015129.6,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:43:00.000Z'}}},
#   {'id': 5994,
#    'name': 'Shiba Inu',
#    'symbol': 'SHIB',
#    'slug': 'shiba-inu',
#    'num_market_pairs': 922,
#    'date_added': '2020-08-01T00:00:00.000Z',
#    'tags': ['memes', 'ethereum-ecosystem', 'doggone-doggerel'],
#    'max_supply': None,
#    'circulating_supply': 589255415932800.1,
#    'total_supply': 589508511902841.1,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'},
#    'infinite_supply': False,
#    'cmc_rank': 14,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:42:00.000Z',
#    'quote': {'USD': {'price': 2.1674547990197083e-05,
#      'volume_24h': 473113357.56664383,
#      'volume_change_24h': -10.6432,
#      'percent_change_1h': -0.79441049,
#      'percent_change_24h': 0.86591631,
#      'percent_change_7d': -0.09160531,
#      'percent_change_30d': -14.9896556,
#      'percent_change_60d': 18.63691558,
#      'percent_change_90d': 10.55223309,
#      'market_cap': 12771844791.119019,
#      'market_cap_dominance': 0.3877,
#      'fully_diluted_market_cap': 12777330531.87,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:42:00.000Z'}}},
#   {'id': 20947,
#    'name': 'Sui',
#    'symbol': 'SUI',
#    'slug': 'sui',
#    'num_market_pairs': 498,
#    'date_added': '2022-07-12T08:03:11.000Z',
#    'tags': ['binance-launchpool',
#     'coinbase-ventures-portfolio',
#     'binance-labs-portfolio',
#     'electric-capital-portfolio',
#     'a16z-portfolio',
#     'sui-ecosystem',
#     'layer-1',
#     'move-vm'],
#    'max_supply': 10000000000,
#    'circulating_supply': 2927660018.558888,
#    'total_supply': 10000000000,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 15,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 4.122579622185296,
#      'volume_24h': 1287467939.5061839,
#      'volume_change_24h': -0.0433,
#      'percent_change_1h': -0.84830586,
#      'percent_change_24h': -1.80835142,
#      'percent_change_7d': -8.42874119,
#      'percent_change_30d': 19.61760849,
#      'percent_change_60d': 140.56801231,
#      'percent_change_90d': 152.0268141,
#      'market_cap': 12069511533.197498,
#      'market_cap_dominance': 0.3691,
#      'fully_diluted_market_cap': 41225796221.85,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 11092,
#    'name': 'Bitget Token',
#    'symbol': 'BGB',
#    'slug': 'bitget-token-new',
#    'num_market_pairs': 27,
#    'date_added': '2021-07-29T00:00:00.000Z',
#    'tags': ['centralized-exchange'],
#    'max_supply': 2000000000,
#    'circulating_supply': 1400000000,
#    'total_supply': 2000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x54D2252757e1672EEaD234D27B1270728fF90581'},
#    'infinite_supply': False,
#    'cmc_rank': 16,
#    'self_reported_circulating_supply': 1400000000,
#    'self_reported_market_cap': 11176255843.987085,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 7.983039888562203,
#      'volume_24h': 1180132978.2411053,
#      'volume_change_24h': -20.4629,
#      'percent_change_1h': -1.83371936,
#      'percent_change_24h': 9.45246563,
#      'percent_change_7d': 92.05131335,
#      'percent_change_30d': 390.68590174,
#      'percent_change_60d': 582.49410131,
#      'percent_change_90d': 666.15663919,
#      'market_cap': 11176255843.987085,
#      'market_cap_dominance': 0.3393,
#      'fully_diluted_market_cap': 15966079777.12,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 512,
#    'name': 'Stellar',
#    'symbol': 'XLM',
#    'slug': 'stellar',
#    'num_market_pairs': 655,
#    'date_added': '2014-08-05T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'enterprise-solutions',
#     'decentralized-exchange-dex-token',
#     'smart-contracts',
#     'hashkey-capital-portfolio',
#     '2017-2018-alt-season'],
#    'max_supply': 50001806812,
#    'circulating_supply': 30275018575.739094,
#    'total_supply': 50001786911.162926,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 17,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 0.35096167097263187,
#      'volume_24h': 301236616.43471414,
#      'volume_change_24h': -7.8833,
#      'percent_change_1h': -1.05668834,
#      'percent_change_24h': -0.75531933,
#      'percent_change_7d': -4.34709736,
#      'percent_change_30d': -29.89653182,
#      'percent_change_60d': 274.36493844,
#      'percent_change_90d': 251.10322534,
#      'market_cap': 10625371108.068861,
#      'market_cap_dominance': 0.3249,
#      'fully_diluted_market_cap': 17548717670.39,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 6636,
#    'name': 'Polkadot',
#    'symbol': 'DOT',
#    'slug': 'polkadot-new',
#    'num_market_pairs': 855,
#    'date_added': '2020-08-19T00:00:00.000Z',
#    'tags': ['substrate',
#     'polkadot',
#     'polkadot-ecosystem',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'arrington-xrp-capital-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'coinfund-portfolio',
#     'fabric-ventures-portfolio',
#     'fenbushi-capital-portfolio',
#     'hashkey-capital-portfolio',
#     'kenetic-capital-portfolio',
#     '1confirmation-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'exnetwork-capital-portfolio',
#     'web3',
#     'spartan-group',
#     'layer-1'],
#    'max_supply': None,
#    'circulating_supply': 1532983075.4471724,
#    'total_supply': 1532983075.4471724,
#    'infinite_supply': True,
#    'platform': None,
#    'cmc_rank': 18,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 6.92835188886965,
#      'volume_24h': 309899280.04927874,
#      'volume_change_24h': -0.1673,
#      'percent_change_1h': -0.50887495,
#      'percent_change_24h': -0.16861286,
#      'percent_change_7d': -2.93011662,
#      'percent_change_30d': -17.43810561,
#      'percent_change_60d': 69.3580438,
#      'percent_change_90d': 44.88819022,
#      'market_cap': 10621046186.379622,
#      'market_cap_dominance': 0.3225,
#      'fully_diluted_market_cap': 10621046186.38,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 4642,
#    'name': 'Hedera',
#    'symbol': 'HBAR',
#    'slug': 'hedera',
#    'num_market_pairs': 303,
#    'date_added': '2019-09-17T00:00:00.000Z',
#    'tags': ['dag',
#     'marketplace',
#     'enterprise-solutions',
#     'defi',
#     'payments',
#     'dcg-portfolio',
#     'hedera-hashgraph-ecosystem',
#     'real-world-assets',
#     'layer-1'],
#    'max_supply': 50000000000,
#    'circulating_supply': 38252162550.06706,
#    'total_supply': 50000000000,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 19,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 0.27733538893264637,
#      'volume_24h': 814773293.4753339,
#      'volume_change_24h': -5.9807,
#      'percent_change_1h': -0.39027501,
#      'percent_change_24h': -3.44536259,
#      'percent_change_7d': 4.59547601,
#      'percent_change_30d': 93.51145939,
#      'percent_change_60d': 473.48393816,
#      'percent_change_90d': 355.81503973,
#      'market_cap': 10608678378.337658,
#      'market_cap_dominance': 0.3244,
#      'fully_diluted_market_cap': 13866769446.63,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 32196,
#    'name': 'Hyperliquid',
#    'symbol': 'HYPE',
#    'slug': 'hyperliquid',
#    'num_market_pairs': 40,
#    'date_added': '2024-07-15T10:14:50.000Z',
#    'tags': ['decentralized-exchange-dex-token',
#     'derivatives',
#     'layer-1',
#     'hyperliquid-ecosystem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 333928180,
#    'total_supply': 999993930,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 20,
#    'self_reported_circulating_supply': 333931719,
#    'self_reported_market_cap': 8951928186.77132,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:43:00.000Z',
#    'quote': {'USD': {'price': 26.80766060073293,
#      'volume_24h': 233190475.8709019,
#      'volume_change_24h': -29.275,
#      'percent_change_1h': 2.13421788,
#      'percent_change_24h': 2.85784177,
#      'percent_change_7d': -8.64266115,
#      'percent_change_30d': 737.66702115,
#      'percent_change_60d': 737.66702115,
#      'percent_change_90d': 737.66702115,
#      'market_cap': 8951833314.460455,
#      'market_cap_dominance': 0.2717,
#      'fully_diluted_market_cap': 26807660600.73,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:43:00.000Z'}}},
#   {'id': 1831,
#    'name': 'Bitcoin Cash',
#    'symbol': 'BCH',
#    'slug': 'bitcoin-cash',
#    'num_market_pairs': 962,
#    'date_added': '2017-07-23T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'sha-256',
#     'marketplace',
#     'medium-of-exchange',
#     'store-of-value',
#     'enterprise-solutions',
#     'payments',
#     'bitcoin-ecosystem',
#     'layer-1',
#     '2017-2018-alt-season'],
#    'max_supply': 21000000,
#    'circulating_supply': 19807668.75,
#    'total_supply': 19807668.75,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 21,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:43:00.000Z',
#    'quote': {'USD': {'price': 442.25665367245375,
#      'volume_24h': 321646635.5624936,
#      'volume_change_24h': 5.0162,
#      'percent_change_1h': -0.49525443,
#      'percent_change_24h': 1.22953448,
#      'percent_change_7d': 0.36641165,
#      'percent_change_30d': -14.51397996,
#      'percent_change_60d': 21.30261793,
#      'percent_change_90d': 25.85831832,
#      'market_cap': 8760073298.427435,
#      'market_cap_dominance': 0.2678,
#      'fully_diluted_market_cap': 9287389727.12,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:43:00.000Z'}}},
#   {'id': 3957,
#    'name': 'UNUS SED LEO',
#    'symbol': 'LEO',
#    'slug': 'unus-sed-leo',
#    'num_market_pairs': 55,
#    'date_added': '2019-05-21T00:00:00.000Z',
#    'tags': ['marketplace',
#     'centralized-exchange',
#     'discount-token',
#     'payments',
#     'kenetic-capital-portfolio',
#     'alameda-research-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 924425211.9,
#    'total_supply': 985239504,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3'},
#    'infinite_supply': False,
#    'cmc_rank': 22,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:43:00.000Z',
#    'quote': {'USD': {'price': 9.16765233533393,
#      'volume_24h': 641586.42073011,
#      'volume_change_24h': -53.7409,
#      'percent_change_1h': 0.06112865,
#      'percent_change_24h': 0.29835958,
#      'percent_change_7d': -1.99266928,
#      'percent_change_30d': 7.00582697,
#      'percent_change_60d': 51.66203485,
#      'percent_change_90d': 54.59878817,
#      'market_cap': 8474808952.716598,
#      'market_cap_dominance': 0.2573,
#      'fully_diluted_market_cap': 9032333239.71,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:43:00.000Z'}}},
#   {'id': 7083,
#    'name': 'Uniswap',
#    'symbol': 'UNI',
#    'slug': 'uniswap',
#    'num_market_pairs': 1151,
#    'date_added': '2020-09-17T00:00:00.000Z',
#    'tags': ['decentralized-exchange-dex-token',
#     'defi',
#     'dao',
#     'yield-farming',
#     'amm',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'governance',
#     'blockchain-capital-portfolio',
#     'defiance-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     'pantera-capital-portfolio',
#     'parafi-capital',
#     'paradigm-portfolio',
#     'arbitrum-ecosytem',
#     'injective-ecosystem',
#     'optimism-ecosystem',
#     'cmc-crypto-awards-2024'],
#    'max_supply': None,
#    'circulating_supply': 600483073.71,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x1f9840a85d5af5bf1d1762f925bdaddc4201f984'},
#    'infinite_supply': False,
#    'cmc_rank': 23,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': 1.53414317,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 13.289563613433488,
#      'volume_24h': 493549452.5888186,
#      'volume_change_24h': 37.6028,
#      'percent_change_1h': -0.63629369,
#      'percent_change_24h': 0.89327077,
#      'percent_change_7d': -0.18204417,
#      'percent_change_30d': -0.28344642,
#      'percent_change_60d': 73.33466365,
#      'percent_change_90d': 75.6539927,
#      'market_cap': 7980158006.859116,
#      'market_cap_dominance': 0.2423,
#      'fully_diluted_market_cap': 13289563613.43,
#      'tvl': 5201703562.71899,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 2,
#    'name': 'Litecoin',
#    'symbol': 'LTC',
#    'slug': 'litecoin',
#    'num_market_pairs': 1296,
#    'date_added': '2013-04-28T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'scrypt',
#     'medium-of-exchange',
#     '2017-2018-alt-season'],
#    'max_supply': 84000000,
#    'circulating_supply': 75354718.30410936,
#    'total_supply': 84000000,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 24,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:43:00.000Z',
#    'quote': {'USD': {'price': 101.91770114659646,
#      'volume_24h': 538960687.7506444,
#      'volume_change_24h': -4.2432,
#      'percent_change_1h': -0.14210459,
#      'percent_change_24h': 0.07575489,
#      'percent_change_7d': 3.04372095,
#      'percent_change_30d': 4.59364589,
#      'percent_change_60d': 43.93460446,
#      'percent_change_90d': 46.51531201,
#      'market_cap': 7679979660.10418,
#      'market_cap_dominance': 0.2337,
#      'fully_diluted_market_cap': 8561086896.31,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:43:00.000Z'}}},
#   {'id': 24478,
#    'name': 'Pepe',
#    'symbol': 'PEPE',
#    'slug': 'pepe',
#    'num_market_pairs': 498,
#    'date_added': '2023-04-17T06:18:08.000Z',
#    'tags': ['memes'],
#    'max_supply': 420690000000000,
#    'circulating_supply': 420689899999994.8,
#    'total_supply': 420689899999994.8,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x6982508145454ce325ddbe47a25d4ec3d2311933'},
#    'infinite_supply': False,
#    'cmc_rank': 25,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:43:00.000Z',
#    'quote': {'USD': {'price': 1.7875619441111886e-05,
#      'volume_24h': 1466346742.3043778,
#      'volume_change_24h': -5.0187,
#      'percent_change_1h': -0.91753695,
#      'percent_change_24h': 3.40350365,
#      'percent_change_7d': 5.07775715,
#      'percent_change_30d': -9.76805567,
#      'percent_change_60d': 92.28510551,
#      'percent_change_90d': 60.41652513,
#      'market_cap': 7520092555.119323,
#      'market_cap_dominance': 0.2283,
#      'fully_diluted_market_cap': 7520094342.68,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:43:00.000Z'}}},
#   {'id': 6535,
#    'name': 'NEAR Protocol',
#    'symbol': 'NEAR',
#    'slug': 'near-protocol',
#    'num_market_pairs': 479,
#    'date_added': '2020-08-11T00:00:00.000Z',
#    'tags': ['platform',
#     'ai-big-data',
#     'staking',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'arrington-xrp-capital-portfolio',
#     'coinfund-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'kenetic-capital-portfolio',
#     'near-protocol-ecosystem',
#     'cross-chain',
#     'injective-ecosystem',
#     'circle-ventures-portfolio',
#     'layer-1',
#     'alleged-sec-securities',
#     'account-abstraction',
#     'data-availability'],
#    'max_supply': None,
#    'circulating_supply': 1217906155,
#    'total_supply': 1227300019,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 26,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 5.134442659746433,
#      'volume_24h': 294347987.9706215,
#      'volume_change_24h': 6.8592,
#      'percent_change_1h': -0.79990464,
#      'percent_change_24h': 1.1191625,
#      'percent_change_7d': -1.85791516,
#      'percent_change_30d': -23.51496241,
#      'percent_change_60d': 20.41007681,
#      'percent_change_90d': -6.37782115,
#      'market_cap': 6253269317.799752,
#      'market_cap_dominance': 0.1899,
#      'fully_diluted_market_cap': 6301501573.86,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 29470,
#    'name': 'Ethena USDe',
#    'symbol': 'USDe',
#    'slug': 'ethena-usde',
#    'num_market_pairs': 98,
#    'date_added': '2024-02-20T11:05:01.000Z',
#    'tags': ['stablecoin',
#     'asset-backed-stablecoin',
#     'binance-labs-portfolio',
#     'dragonfly-capital-portfolio',
#     'usd-stablecoin',
#     'eigenlayer-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 5914976459.482459,
#    'total_supply': 5914976459.482459,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x4c9edd5852cd905f086c759e8383e09bff1e68b3'},
#    'infinite_supply': True,
#    'cmc_rank': 27,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 0.9975969785185205,
#      'volume_24h': 95471801.06325597,
#      'volume_change_24h': -20.8927,
#      'percent_change_1h': -0.0181732,
#      'percent_change_24h': -0.05525922,
#      'percent_change_7d': -0.15779359,
#      'percent_change_30d': -0.36497386,
#      'percent_change_60d': -0.30509373,
#      'percent_change_90d': -0.1993966,
#      'market_cap': 5900762643.987877,
#      'market_cap_dominance': 0.1804,
#      'fully_diluted_market_cap': 5900762643.99,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 4943,
#    'name': 'Dai',
#    'symbol': 'DAI',
#    'slug': 'multi-collateral-dai',
#    'num_market_pairs': 3429,
#    'date_added': '2019-11-22T00:00:00.000Z',
#    'tags': ['defi',
#     'stablecoin',
#     'asset-backed-stablecoin',
#     'ethereum-ecosystem',
#     'avalanche-ecosystem',
#     'polygon-ecosystem',
#     'fantom-ecosystem',
#     'arbitrum-ecosytem',
#     'harmony-ecosystem',
#     'moonriver-ecosystem',
#     'bnb-chain',
#     'usd-stablecoin',
#     'optimism-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 5365382702.664872,
#    'total_supply': 5365382702.664872,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x6b175474e89094c44da98b954eedeac495271d0f'},
#    'infinite_supply': True,
#    'cmc_rank': 28,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 0.9999201090251812,
#      'volume_24h': 109643603.76932988,
#      'volume_change_24h': -17.7951,
#      'percent_change_1h': 0.01559137,
#      'percent_change_24h': 0.0192829,
#      'percent_change_7d': -0.0059949,
#      'percent_change_30d': -0.02387639,
#      'percent_change_60d': -0.01054677,
#      'percent_change_90d': 0.00199962,
#      'market_cap': 5364954057.010481,
#      'market_cap_dominance': 0.1641,
#      'fully_diluted_market_cap': 5364954057.01,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 8916,
#    'name': 'Internet Computer',
#    'symbol': 'ICP',
#    'slug': 'internet-computer',
#    'num_market_pairs': 309,
#    'date_added': '2021-03-23T00:00:00.000Z',
#    'tags': ['platform',
#     'ai-big-data',
#     'smart-contracts',
#     'polychain-capital-portfolio',
#     'electric-capital-portfolio',
#     'fenbushi-capital-portfolio',
#     'hashkey-capital-portfolio',
#     'a16z-portfolio',
#     'multicoin-capital-portfolio',
#     'exnetwork-capital-portfolio',
#     'internet-computer-ecosystem',
#     'layer-1',
#     'alleged-sec-securities'],
#    'max_supply': None,
#    'circulating_supply': 478095310.6066825,
#    'total_supply': 527845303.2587222,
#    'infinite_supply': True,
#    'platform': None,
#    'cmc_rank': 29,
#    'self_reported_circulating_supply': 478095310.6066825,
#    'self_reported_market_cap': 4905493326.953625,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 10.260492454378529,
#      'volume_24h': 179843657.1125035,
#      'volume_change_24h': -6.4438,
#      'percent_change_1h': -0.25820309,
#      'percent_change_24h': -0.27614066,
#      'percent_change_7d': 0.03054696,
#      'percent_change_30d': -11.52836612,
#      'percent_change_60d': 32.31682345,
#      'percent_change_90d': 7.00321763,
#      'market_cap': 4905493326.953625,
#      'market_cap_dominance': 0.1489,
#      'fully_diluted_market_cap': 5415952751.17,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 21794,
#    'name': 'Aptos',
#    'symbol': 'APT',
#    'slug': 'aptos',
#    'num_market_pairs': 466,
#    'date_added': '2022-10-19T01:50:25.000Z',
#    'tags': ['binance-labs-portfolio',
#     'aptos-ecosystem',
#     'circle-ventures-portfolio',
#     'layer-1',
#     'ftx-bankruptcy-estate',
#     'move-vm'],
#    'max_supply': None,
#    'circulating_supply': 557080163.1463939,
#    'total_supply': 1133025805.071848,
#    'infinite_supply': True,
#    'platform': None,
#    'cmc_rank': 30,
#    'self_reported_circulating_supply': 130000000,
#    'self_reported_market_cap': 1139157234.974739,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 8.762747961344147,
#      'volume_24h': 332584610.34362733,
#      'volume_change_24h': 14.9895,
#      'percent_change_1h': -0.48703293,
#      'percent_change_24h': -1.03833605,
#      'percent_change_7d': -17.45336796,
#      'percent_change_30d': -29.97309166,
#      'percent_change_60d': -4.17326319,
#      'percent_change_90d': 9.52765941,
#      'market_cap': 4881553063.916327,
#      'market_cap_dominance': 0.1493,
#      'fully_diluted_market_cap': 9928419563.54,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 7278,
#    'name': 'Aave',
#    'symbol': 'AAVE',
#    'slug': 'aave',
#    'num_market_pairs': 994,
#    'date_added': '2020-10-02T00:00:00.000Z',
#    'tags': ['defi',
#     'dao',
#     'yield-farming',
#     'three-arrows-capital-portfolio',
#     'governance',
#     'lending-borowing',
#     'blockchain-capital-portfolio',
#     'defiance-capital-portfolio',
#     'framework-ventures-portfolio',
#     'alameda-research-portfolio',
#     'pantera-capital-portfolio',
#     'parafi-capital',
#     'polygon-ecosystem',
#     'fantom-ecosystem',
#     'optimism-ecosystem',
#     'standard-crypto-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 15031896.30986425,
#    'total_supply': 16000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x7Fc66500c84A76Ad7e9c93437bFc5Ac33E2DDaE9'},
#    'infinite_supply': False,
#    'cmc_rank': 31,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': 0.2390338,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 323.6269056725002,
#      'volume_24h': 685871214.436657,
#      'volume_change_24h': 22.0504,
#      'percent_change_1h': -0.70221426,
#      'percent_change_24h': -3.24351976,
#      'percent_change_7d': -0.03901029,
#      'percent_change_30d': 60.34921693,
#      'percent_change_60d': 114.13851112,
#      'percent_change_90d': 98.18785842,
#      'market_cap': 4864726089.151241,
#      'market_cap_dominance': 0.1488,
#      'fully_diluted_market_cap': 5178030490.76,
#      'tvl': 20351624011.28871,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 28321,
#    'name': 'POL (ex-MATIC)',
#    'symbol': 'POL',
#    'slug': 'polygon-ecosystem-token',
#    'num_market_pairs': 404,
#    'date_added': '2023-10-30T14:43:57.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 8399417327.08665,
#    'total_supply': 10326838970.968012,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x455e53cbb86018ac2b8092fdcd39d8444affc3f6'},
#    'infinite_supply': False,
#    'cmc_rank': 32,
#    'self_reported_circulating_supply': 62242397.94040099,
#    'self_reported_market_cap': 29956877.683657516,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 0.4812937591566146,
#      'volume_24h': 204395740.0771848,
#      'volume_change_24h': 8.6978,
#      'percent_change_1h': -0.61285533,
#      'percent_change_24h': 1.0959989,
#      'percent_change_7d': -0.58402418,
#      'percent_change_30d': -15.62322576,
#      'percent_change_60d': 49.35388735,
#      'percent_change_90d': 14.01026834,
#      'market_cap': 4042587140.0787377,
#      'market_cap_dominance': 0.123,
#      'fully_diluted_market_cap': 4970243148.54,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 27075,
#    'name': 'Mantle',
#    'symbol': 'MNT',
#    'slug': 'mantle',
#    'num_market_pairs': 102,
#    'date_added': '2023-07-17T11:00:31.000Z',
#    'tags': ['ethereum-ecosystem', 'layer-2', 'dwf-labs-portfolio'],
#    'max_supply': 6219316795,
#    'circulating_supply': 3366841707.8368406,
#    'total_supply': 6219316794.99,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x3c3a81e81dc49a522a592e7622a7e711c06bf354'},
#    'infinite_supply': False,
#    'cmc_rank': 33,
#    'self_reported_circulating_supply': 3366841707.8368406,
#    'self_reported_market_cap': 4017637673.8291426,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 1.1932956825613377,
#      'volume_24h': 172447481.73203224,
#      'volume_change_24h': 15.7646,
#      'percent_change_1h': -0.82817729,
#      'percent_change_24h': 1.59157037,
#      'percent_change_7d': -2.30369877,
#      'percent_change_30d': 37.57677915,
#      'percent_change_60d': 105.73453636,
#      'percent_change_90d': 86.77420195,
#      'market_cap': 4017637673.8291426,
#      'market_cap_dominance': 0.1223,
#      'fully_diluted_market_cap': 7421483879.95,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 3635,
#    'name': 'Cronos',
#    'symbol': 'CRO',
#    'slug': 'cronos',
#    'num_market_pairs': 267,
#    'date_added': '2018-12-14T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'cosmos-ecosystem',
#     'centralized-exchange',
#     'mobile',
#     'payments',
#     'injective-ecosystem',
#     'layer-1'],
#    'max_supply': None,
#    'circulating_supply': 26571560696,
#    'total_supply': 30000000000,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 34,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:43:00.000Z',
#    'quote': {'USD': {'price': 0.1490417273764479,
#      'volume_24h': 30033410.16187968,
#      'volume_change_24h': 0.3131,
#      'percent_change_1h': -0.39366417,
#      'percent_change_24h': -0.04040355,
#      'percent_change_7d': -5.5507152,
#      'percent_change_30d': -18.03620084,
#      'percent_change_60d': 101.44926819,
#      'percent_change_90d': 73.67224273,
#      'market_cap': 3960271305.2199707,
#      'market_cap_dominance': 0.1202,
#      'fully_diluted_market_cap': 4471251821.29,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:43:00.000Z'}}},
#   {'id': 1321,
#    'name': 'Ethereum Classic',
#    'symbol': 'ETC',
#    'slug': 'ethereum-classic',
#    'num_market_pairs': 586,
#    'date_added': '2016-07-24T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'ethash',
#     'platform',
#     'smart-contracts',
#     'dcg-portfolio',
#     '2017-2018-alt-season'],
#    'max_supply': 210700000,
#    'circulating_supply': 150116288.90751544,
#    'total_supply': 210700000,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 35,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:43:00.000Z',
#    'quote': {'USD': {'price': 26.04559934759666,
#      'volume_24h': 203848336.93690002,
#      'volume_change_24h': -9.3988,
#      'percent_change_1h': -0.64785628,
#      'percent_change_24h': 1.21601,
#      'percent_change_7d': -2.58372105,
#      'percent_change_30d': -15.96393096,
#      'percent_change_60d': 38.52633117,
#      'percent_change_90d': 26.91093324,
#      'market_cap': 3909868716.4332156,
#      'market_cap_dominance': 0.1187,
#      'fully_diluted_market_cap': 5487807782.54,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:43:00.000Z'}}},
#   {'id': 3077,
#    'name': 'VeChain',
#    'symbol': 'VET',
#    'slug': 'vechain',
#    'num_market_pairs': 315,
#    'date_added': '2017-08-22T00:00:00.000Z',
#    'tags': ['logistics',
#     'data-provenance',
#     'iot',
#     'smart-contracts',
#     'fenbushi-capital-portfolio',
# ...
#    'circulating_supply': 10000,
#    'total_supply': 10000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x9e9fbde7c7a83c43913bddc8779158f1368f0413'},
#    'infinite_supply': False,
#    'cmc_rank': 988,
#    'self_reported_circulating_supply': 8000,
#    'self_reported_market_cap': 13938421.696611173,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:43:00.000Z',
#    'quote': {'USD': {'price': 1742.3027120763966,
#      'volume_24h': 3186757.84571481,
#      'volume_change_24h': 21.6491,
#      'percent_change_1h': -0.0445974,
#      'percent_change_24h': -3.43967315,
#      'percent_change_7d': -10.13943056,
#      'percent_change_30d': -15.95241625,
#      'percent_change_60d': 19.868737,
#      'percent_change_90d': 14.42838548,
#      'market_cap': 17423027.120763965,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 17423027.12,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:43:00.000Z'}}},
#   {'id': 213,
#    'name': 'MonaCoin',
#    'symbol': 'MONA',
#    'slug': 'monacoin',
#    'num_market_pairs': 23,
#    'date_added': '2014-03-20T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'lyra2rev2',
#     'medium-of-exchange',
#     'memes',
#     'payments'],
#    'max_supply': 105120000,
#    'circulating_supply': 65729674.871168,
#    'total_supply': 65729674.871168,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 989,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 0.2646821210627159,
#      'volume_24h': 187637.93016018,
#      'volume_change_24h': 9.2859,
#      'percent_change_1h': -4.95529181,
#      'percent_change_24h': 0.1457905,
#      'percent_change_7d': -4.93716702,
#      'percent_change_30d': -20.38618508,
#      'percent_change_60d': -2.59659921,
#      'percent_change_90d': 7.3458162,
#      'market_cap': 17397469.761663444,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 27823384.57,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 34587,
#    'name': 'Frodo the virtual samurai',
#    'symbol': 'FROG',
#    'slug': 'frodo-the-virtual-samurai',
#    'num_market_pairs': 15,
#    'date_added': '2024-12-12T22:29:17.000Z',
#    'tags': ['memes', 'binance-alpha'],
#    'max_supply': 5000000000,
#    'circulating_supply': 5000000000,
#    'total_supply': 5000000000,
#    'platform': {'id': 1839,
#     'name': 'BNB Smart Chain (BEP20)',
#     'symbol': 'BNB',
#     'slug': 'bnb',
#     'token_address': '0x4AD663403df2F0E7987bC9C74561687472e1611C'},
#    'infinite_supply': False,
#    'cmc_rank': 990,
#    'self_reported_circulating_supply': 5000000000,
#    'self_reported_market_cap': 17291241.14726779,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:43:00.000Z',
#    'quote': {'USD': {'price': 0.0034582482294535574,
#      'volume_24h': 702559.58089971,
#      'volume_change_24h': 1.3186,
#      'percent_change_1h': 0.02708218,
#      'percent_change_24h': 1.07003242,
#      'percent_change_7d': -38.29213078,
#      'percent_change_30d': 54.44716887,
#      'percent_change_60d': 54.44716887,
#      'percent_change_90d': 54.44716887,
#      'market_cap': 17291241.14726779,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 17291241.15,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:43:00.000Z'}}},
#   {'id': 6739,
#    'name': 'LumiWave',
#    'symbol': 'LWA',
#    'slug': 'lumiwave',
#    'num_market_pairs': 14,
#    'date_added': '2020-08-28T00:00:00.000Z',
#    'tags': ['sui-ecosystem'],
#    'max_supply': 770075466,
#    'circulating_supply': 770075466,
#    'total_supply': 770075466,
#    'platform': {'id': 20947,
#     'name': 'Sui Network',
#     'symbol': 'SUI',
#     'slug': 'sui',
#     'token_address': '0x3332b178c1513f32bca9cf711b0318c2bca4cb06f1a74211bac97a1eeb7f7259::LWA::LWA'},
#    'infinite_supply': False,
#    'cmc_rank': 991,
#    'self_reported_circulating_supply': 770075466,
#    'self_reported_market_cap': 17265979.961108603,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 0.022421153151123245,
#      'volume_24h': 512145.21047332,
#      'volume_change_24h': -11.6866,
#      'percent_change_1h': -0.48071317,
#      'percent_change_24h': -0.25810062,
#      'percent_change_7d': -1.17069406,
#      'percent_change_30d': -11.04816344,
#      'percent_change_60d': 0.87252003,
#      'percent_change_90d': -5.53266415,
#      'market_cap': 17265979.961108603,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 17265979.96,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 32940,
#    'name': 'Philtoken',
#    'symbol': 'PHIL',
#    'slug': 'philtoken',
#    'num_market_pairs': 31,
#    'date_added': '2024-09-05T05:24:44.000Z',
#    'tags': ['memes', 'ethereum-ecosystem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 1000000000,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xc328a59E7321747aEBBc49FD28d1b32C1af8d3b2'},
#    'infinite_supply': False,
#    'cmc_rank': 992,
#    'self_reported_circulating_supply': 1000000000,
#    'self_reported_market_cap': 17258845.35458074,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 0.01725884535458074,
#      'volume_24h': 9449959.739795,
#      'volume_change_24h': 16.9519,
#      'percent_change_1h': 0.59919994,
#      'percent_change_24h': 0.4784793,
#      'percent_change_7d': 0.80524575,
#      'percent_change_30d': -39.13517813,
#      'percent_change_60d': -52.7206691,
#      'percent_change_90d': -19.21208382,
#      'market_cap': 17258845.35458074,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 17258845.35,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 28443,
#    'name': 'Verified USD',
#    'symbol': 'USDV',
#    'slug': 'verified-usd',
#    'num_market_pairs': 141,
#    'date_added': '2023-11-17T11:56:26.000Z',
#    'tags': ['stablecoin',
#     'asset-backed-stablecoin',
#     'usd-stablecoin',
#     'fiat-stablecoin'],
#    'max_supply': None,
#    'circulating_supply': 17141815,
#    'total_supply': 17141815,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x0e573ce2736dd9637a0b21058352e1667925c7a8'},
#    'infinite_supply': False,
#    'cmc_rank': 993,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 0.9964858183766729,
#      'volume_24h': 11713.29724567,
#      'volume_change_24h': -20.9492,
#      'percent_change_1h': 0.18656111,
#      'percent_change_24h': 0.14027137,
#      'percent_change_7d': -0.29738359,
#      'percent_change_30d': -0.36743028,
#      'percent_change_60d': -0.25538892,
#      'percent_change_90d': -0.04936053,
#      'market_cap': 17081575.548736528,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 17081575.55,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 7703,
#    'name': 'MileVerse',
#    'symbol': 'MVC',
#    'slug': 'mileverse',
#    'num_market_pairs': 5,
#    'date_added': '2020-11-17T00:00:00.000Z',
#    'tags': [],
#    'max_supply': 3000000000,
#    'circulating_supply': 2761029999.334,
#    'total_supply': 3000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x581911b360B6eB3a14eF295a83a91DC2bCE2D6f7'},
#    'infinite_supply': False,
#    'cmc_rank': 994,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 0.006175954611164147,
#      'volume_24h': 2353658.94081577,
#      'volume_change_24h': -54.1913,
#      'percent_change_1h': 0.54567997,
#      'percent_change_24h': -0.427978,
#      'percent_change_7d': -3.13757055,
#      'percent_change_30d': 41.79504407,
#      'percent_change_60d': 50.95296984,
#      'percent_change_90d': 31.64669672,
#      'market_cap': 17051995.95594936,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 18527863.83,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 29037,
#    'name': 'Gaimin',
#    'symbol': 'GMRX',
#    'slug': 'gaimin',
#    'num_market_pairs': 34,
#    'date_added': '2024-03-26T04:01:53.000Z',
#    'tags': ['platform',
#     'ai-big-data',
#     'distributed-computing',
#     'collectibles-nfts',
#     'gaming',
#     'dapp',
#     'binance-smart-chain',
#     'fan-token',
#     'layer-2',
#     'solana-ecosystem',
#     'seedify',
#     'depin',
#     'cmc-labs'],
#    'max_supply': None,
#    'circulating_supply': 24731000000,
#    'total_supply': 99996000000,
#    'platform': {'id': 1839,
#     'name': 'BNB Smart Chain (BEP20)',
#     'symbol': 'BNB',
#     'slug': 'bnb',
#     'token_address': '0x998305efDC264b9674178899FFfBb44a47134a76'},
#    'infinite_supply': False,
#    'cmc_rank': 995,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:43:00.000Z',
#    'quote': {'USD': {'price': 0.0006885818832292656,
#      'volume_24h': 214066.18818277,
#      'volume_change_24h': -11.5334,
#      'percent_change_1h': -0.13820793,
#      'percent_change_24h': 1.57984006,
#      'percent_change_7d': -4.87582684,
#      'percent_change_30d': -12.5146706,
#      'percent_change_60d': 30.09010351,
#      'percent_change_90d': -29.55614275,
#      'market_cap': 17029318.554142967,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 68855434,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:43:00.000Z'}}},
#   {'id': 23295,
#    'name': 'Veno Finance',
#    'symbol': 'VNO',
#    'slug': 'veno-finance-vno',
#    'num_market_pairs': 27,
#    'date_added': '2023-01-20T11:18:48.000Z',
#    'tags': [],
#    'max_supply': 2000000000,
#    'circulating_supply': 474514554,
#    'total_supply': 1844674055,
#    'platform': {'id': 3635,
#     'name': 'Cronos',
#     'symbol': 'CRO',
#     'slug': 'cronos',
#     'token_address': '0xdb7d0a1ec37de1de924f8e8adac6ed338d4404e9'},
#    'infinite_supply': False,
#    'cmc_rank': 997,
#    'self_reported_circulating_supply': 163476863.5,
#    'self_reported_market_cap': 5858838.960901948,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 0.0358389489219797,
#      'volume_24h': 8936.55188542,
#      'volume_change_24h': -42.0661,
#      'percent_change_1h': -0.50838213,
#      'percent_change_24h': -0.7300401,
#      'percent_change_7d': -8.63129216,
#      'percent_change_30d': 8.47581769,
#      'percent_change_60d': 79.06699473,
#      'percent_change_90d': 37.28943918,
#      'market_cap': 17006102.86354198,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 71677897.84,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 22892,
#    'name': 'Atlas Navi',
#    'symbol': 'NAVI',
#    'slug': 'atlas-navi',
#    'num_market_pairs': 10,
#    'date_added': '2022-12-06T10:29:10.000Z',
#    'tags': ['ai-big-data', 'distributed-computing', 'depin'],
#    'max_supply': 300000000,
#    'circulating_supply': 109928997.87627798,
#    'total_supply': 300000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xfc1c93a2507975e98b9d0e9260ded61a00152bf1'},
#    'infinite_supply': False,
#    'cmc_rank': 997,
#    'self_reported_circulating_supply': 161706684,
#    'self_reported_market_cap': 25011513.353935435,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:43:00.000Z',
#    'quote': {'USD': {'price': 0.15467210590958277,
#      'volume_24h': 134881.73805419,
#      'volume_change_24h': 18.897,
#      'percent_change_1h': -0.55582136,
#      'percent_change_24h': 1.20637937,
#      'percent_change_7d': -13.95813046,
#      'percent_change_30d': -19.2985276,
#      'percent_change_60d': 35.68500059,
#      'percent_change_90d': 4.44017393,
#      'market_cap': 17002949.602053966,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 46401631.77,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:43:00.000Z'}}},
#   {'id': 11222,
#    'name': 'Nine Chronicles',
#    'symbol': 'WNCG',
#    'slug': 'wrapped-ncg',
#    'num_market_pairs': 44,
#    'date_added': '2021-08-11T00:00:00.000Z',
#    'tags': ['binance-labs-portfolio',
#     'animoca-brands-portfolio',
#     'skyvision-capital-portfolio',
#     'dwf-labs-portfolio'],
#    'max_supply': 1000000000,
#    'circulating_supply': 453344140.85,
#    'total_supply': 723789440,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xf203Ca1769ca8e9e8FE1DA9D147DB68B6c919817'},
#    'infinite_supply': False,
#    'cmc_rank': 998,
#    'self_reported_circulating_supply': 453345470.85,
#    'self_reported_market_cap': 16927015.95233817,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 0.03733800609191234,
#      'volume_24h': 174565.46196049,
#      'volume_change_24h': -31.7215,
#      'percent_change_1h': -0.80975838,
#      'percent_change_24h': -0.66729898,
#      'percent_change_7d': -7.45781809,
#      'percent_change_30d': -13.53200255,
#      'percent_change_60d': -4.19040112,
#      'percent_change_90d': -21.1328952,
#      'market_cap': 16926966.292790066,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 37338006.09,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 23751,
#    'name': 'Artyfact',
#    'symbol': 'ARTY',
#    'slug': 'artyfact',
#    'num_market_pairs': 40,
#    'date_added': '2023-03-03T10:44:47.000Z',
#    'tags': ['gaming', 'binance-smart-chain'],
#    'max_supply': 25000000,
#    'circulating_supply': 19480227,
#    'total_supply': 24958618,
#    'platform': {'id': 1839,
#     'name': 'BNB Smart Chain (BEP20)',
#     'symbol': 'BNB',
#     'slug': 'bnb',
#     'token_address': '0x617Cab4aAae1f8dfb3eE138698330776a1e1b324'},
#    'infinite_supply': False,
#    'cmc_rank': 999,
#    'self_reported_circulating_supply': 21317727,
#    'self_reported_market_cap': 18488172.611546073,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:41:00.000Z',
#    'quote': {'USD': {'price': 0.8672675380234521,
#      'volume_24h': 6922897.68805395,
#      'volume_change_24h': -34.0536,
#      'percent_change_1h': -0.54674435,
#      'percent_change_24h': -0.77143851,
#      'percent_change_7d': -13.76685369,
#      'percent_change_30d': 73.08510199,
#      'percent_change_60d': 122.30670411,
#      'percent_change_90d': 69.10312945,
#      'market_cap': 16894568.510427978,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 21681688.45,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:41:00.000Z'}}},
#   {'id': 34422,
#    'name': 'Build On BNB',
#    'symbol': 'BOB',
#    'slug': 'build-on-bnb',
#    'num_market_pairs': 4,
#    'date_added': '2024-12-05T09:32:49.000Z',
#    'tags': ['memes', 'binance-alpha'],
#    'max_supply': 420690000000000,
#    'circulating_supply': 420690000000000,
#    'total_supply': 420690000000000,
#    'platform': {'id': 1839,
#     'name': 'BNB Smart Chain (BEP20)',
#     'symbol': 'BNB',
#     'slug': 'bnb',
#     'token_address': '0x51363F073b1E4920fdA7AA9E9d84BA97EdE1560e'},
#    'infinite_supply': False,
#    'cmc_rank': 1000,
#    'self_reported_circulating_supply': 420690000000000,
#    'self_reported_market_cap': 16859886.619381294,
#    'tvl_ratio': None,
#    'last_updated': '2024-12-27T21:43:00.000Z',
#    'quote': {'USD': {'price': 4.0076746819228635e-08,
#      'volume_24h': 586372.37033886,
#      'volume_change_24h': -45.9099,
#      'percent_change_1h': -1.69857419,
#      'percent_change_24h': 3.05146859,
#      'percent_change_7d': -1.17708244,
#      'percent_change_30d': 17.11981074,
#      'percent_change_60d': 17.11981074,
#      'percent_change_90d': 17.11981074,
#      'market_cap': 16859886.619381294,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 16859886.62,
#      'tvl': None,
#      'last_updated': '2024-12-27T21:43:00.000Z'}}},
#   ...]}

# %% [markdown]
# ### Exploring API endpoints and exploring what can be useful

# %% [markdown]
# #### 1) Cryptocurrency metadata
# - According to documentation, we could be doing the API call using parameters *slug* or *symbol*, but symbol would return every cryptocurrency associated to the value passed (for example, by searching for *BTC* we would find other cryptocurrencies beyond the usual bitcoin)

# %%
# defining the full query URL
metadata_url= base_url+'/v2/cryptocurrency/info'

# defining the appropriate parameters (I want to see basic information involving some of the main recent cryptocurrencies)
parameters= {
    'symbol': 'BTC,ETH,USDT,USDC,BNB,XRP,ADA,BUSD,SOL,DOT'
}
# Here we are using the symbol parameter in order to include 'Binance USD (BUSD)', 'Binance Coin (BNB)' and 'USD Coin (USDC)' in the search since their names have spaces and we could not specify them on slug argument. 

# But by doing it is important to emphasize a thing: using symbol parameter, the API will return to us any reference it has for such symbol stored in the endpoint we are calling (and it might not necessarily be a crypto). So we'll have to filter it later on

# making the call attempt
response= r.get(
    url= metadata_url
    ,params= parameters
    ,headers= headers
)

print(response.status_code)
print(response.reason)

# printing the entire response to take a look at the error message if there's a HTTP expection of type 4xx (i.e., user inconsistency)
if str(response.status_code)[0] == '4':
    print(response.json())
# Out:
# 200
# OK

# %%
# special treatment to handle all returned data and compile it on a single dataframe
crypto_symbols= ['BTC','ETH','USDT','USDC','BNB','XRP','ADA','BUSD','SOL','DOT']
df_data= []

for crypto in crypto_symbols:
    aux_df= pd.json_normalize(response.json()['data'][crypto])
    df_data.append(aux_df)

df= pd.concat(df_data, ignore_index= True)
df.head()
# Out:
# C:\Users\LUCAS\AppData\Local\Temp\ipykernel_18952\3920442243.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df= pd.concat(df_data, ignore_index= True)
#       id                         name symbol category  \
# 0      1                      Bitcoin    BTC     coin
# 1  34316  HarryPotterTrumpSonic100Inu    BTC    token
# 2  31652                       batcat    BTC    token
# 3  30938            Satoshi Pumpomoto    BTC    token
# 4  31469         Boost Trump Campaign    BTC    token
#
#                                          description  \
# 0  Bitcoin (BTC) is a cryptocurrency launched in ...
# 1  HarryPotterTrumpSonic100Inu (BTC) is a cryptoc...
# 2  batcat (BTC) is a cryptocurrency launched in 2...
# 3  Satoshi Pumpomoto (BTC) is a cryptocurrency la...
# 4  Boost Trump Campaign (BTC) is a cryptocurrency...
#
#                           slug  \
# 0                      bitcoin
# 1  harrypottertrumpsonic100inu
# 2                       batcat
# 3            satoshi-pumpomoto
# 4         boost-trump-campaign
#
#                                                 logo subreddit notice  \
# 0  https://s2.coinmarketcap.com/static/img/coins/...   bitcoin
# 1  https://s2.coinmarketcap.com/static/img/coins/...
# 2  https://s2.coinmarketcap.com/static/img/coins/...
# 3  https://s2.coinmarketcap.com/static/img/coins/...
# 4  https://s2.coinmarketcap.com/static/img/coins/...
#
#                                                 tags  ...  \
# 0  [mineable, pow, sha-256, store-of-value, state...  ...
# 1                                            [memes]  ...
# 2                          [memes, solana-ecosystem]  ...
# 3                                               None  ...
# 4                                               None  ...
#
#                                        urls.explorer  \
# 0  [https://blockchain.info/, https://live.blockc...
# 1  [https://etherscan.io/token/0x7099ab9e42fa7327...
# 2  [https://solscan.io/token/EtBc6gkCvsB9c6f5wSbw...
# 3  [https://solscan.io/token/6AGNtEgBE2jph1bWFdya...
# 4  [https://etherscan.io/token/0x300e0d87f8c95d90...
#
#                       urls.reddit                 urls.technical_doc  \
# 0  [https://reddit.com/r/bitcoin]  [https://bitcoin.org/bitcoin.pdf]
# 1                              []                                 []
# 2                              []                                 []
# 3                              []                                 []
# 4                              []                                 []
#
#                        urls.source_code urls.announcement  platform.id  \
# 0  [https://github.com/bitcoin/bitcoin]                []          NaN
# 1                                    []                []         1027
# 2                                    []                []         5426
# 3                                    []                []         5426
# 4                                    []                []         1027
#
#   platform.name platform.slug  platform.symbol  \
# 0           NaN           NaN              NaN
# 1      Ethereum      ethereum              ETH
# 2        Solana        solana              SOL
# 3        Solana        solana              SOL
# 4      Ethereum      ethereum              ETH
#
#                          platform.token_address
# 0                                           NaN
# 1    0x7099aB9E42Fa7327a6b15E0a0c120c3e50d11BeC
# 2  EtBc6gkCvsB9c6f5wSbwG8wPjRqXMB5euptK6bqG1R4X
# 3  6AGNtEgBE2jph1bWFdyaqsXJ762emaP9RE17kKxEsfiV
# 4    0x300e0d87f8c95d90cfe4b809baa3a6c90e83b850
#
# [5 rows x 37 columns]

# %%
df['category'].unique() # checking different categories of the extracted data
# Out:
# array(['coin', 'token'], dtype=object)

# %% [markdown]
# - As we previously mentioned, by filtering the query with the *symbol* argument we allow it to return to us different results that are not exclusively related to cryptos. We have te filter that

# %%
df= df[df['category'] == 'coin'] # applying filter on DataFrame

# %%
df['category'].unique() # checking the result
# Out:
# array(['coin'], dtype=object)

# %%
df.isna().sum() # verifying the quantity of null values inside the dataframe
# Out:
# id                                  0
# name                                0
# symbol                              0
# category                            0
# description                         0
# slug                                0
# logo                                0
# subreddit                           0
# notice                              0
# tags                                0
# tag-names                           0
# tag-groups                          0
# platform                            8
# date_added                          0
# twitter_username                    0
# is_hidden                           0
# date_launched                       5
# contract_address                    0
# self_reported_circulating_supply    8
# self_reported_tags                  6
# self_reported_market_cap            8
# infinite_supply                     0
# urls.website                        0
# urls.twitter                        0
# urls.message_board                  0
# urls.chat                           0
# urls.facebook                       0
# urls.explorer                       0
# urls.reddit                         0
# urls.technical_doc                  0
# urls.source_code                    0
# urls.announcement                   0
# platform.id                         5
# platform.name                       5
# platform.slug                       5
# platform.symbol                     5
# platform.token_address              5
# dtype: int64

# %%
# saving a final csv file
df.to_csv('API-data/cryptocurrency_metada.csv', sep= ';', index= False)

# %% [markdown]
# #### 2) Cryptocurrency quotes

# %% [markdown]
# #### 3) Cryptocurrency market
