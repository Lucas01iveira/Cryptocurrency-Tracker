# %% [markdown]
# ### CoinMarketCap Study
# - API documentation is enable to be read in https://coinmarketcap.com/api/documentation/v1/#

# %% [markdown]
# ### Health-Check

# %%
import requests as r
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import os
import pandas as pd

# %% [markdown]
# - Testing the API connection in the sandbox environment

# %%
test_url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'b54bcf4d-1bca-4e8e-9a24-22ff2c3d462c',
}

session = r.Session()
session.headers.update(headers)

try:
  response = session.get(test_url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2025-01-02T14:23:45.001Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 1862, 'name': 'bgmejx6ys5', 'symbol': 'vhi4ef2cj7e', 'slug': 'f76nt9f1drt', 'cmc_rank': 5286, 'num_market_pairs': 145, 'circulating_supply': 1889, 'total_supply': 561, 'max_supply': 5160, 'infinite_supply': None, 'last_updated': '2025-01-02T14:23:45.001Z', 'date_added': '2025-01-02T14:23:45.001Z', 'tags': ['92twp2cucq', 'rcjrcjm63ac', '3jcf2cuvxlg', 'gxj6wdkwf8b', '0s3td18rnaia', 'fo2u579qcnh', 'hmvafacuz97', '1teatf1l78r', 'lx1p2qstexe', 'l4svmy6zua'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.33594552966837066, 'volume_24h': 8192, 'volume_change_24h': 0.6893784067602771, 'percent_change_1h': 0.28900017226681607, 'percent_change_24h': 0.4486020260212198, 'percent_change_7d': 0.07207359809951153, 'market_cap': 0.638076277442853, 'market_cap_dominance': 4640, 'fully_diluted_market_cap': 0.9757786003493472, 'last_updated': '2025-01-02T14:23:45.001Z'}}}, {'id': 1966, 'name': 'xzqqz5mmfo', 'symbol': 'b0tqk8ztfl', 'slug': 'pns44h78s9', 'cmc_rank': 7803, 'num_market_pairs': 6894, 'circulating_supply': 5592, 'total_supply': 7172, 'max_supply': 1819, 'infinite_supply': None, 'last_updated': '2025-01-02T14:23:45.001Z', 'date_added': '2025-01-02T14:23:45.001Z', 'tags': ['hh3srdnovjc', 'mu67kwx42b', '35413fuo4f', 'mk48b78x1t', '2in710xt7th', '318v7sr75d2', 'cnkt7d245mt', 'oh9pcqd9h7', 'qyf45a9mia', '2vn73rfa4rd'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.7825223671283916, 'volume_24h': 9707, 'volume_change_24h': 0.5185274725837394, 'percent_change_1h': 0.7031421401694937, 'percent_change_24h': 0.32926814489083434, 'percent_change_7d': 0.7139175341158772, 'market_cap': 0.8491734545290901, 'market_cap_dominance': 8567, 'fully_diluted_market_cap': 0.7074436802325816, 'last_updated': '2025-01-02T14:23:45.001Z'}}}, {'id': 9722, 'name': '8c8e4v3tub3', 'symbol': 'gqpx5jpngb', 'slug': 'h6yulsky3ts', 'cmc_rank': 5446, 'num_market_pairs': 8044, 'circulating_supply': 4993, 'total_supply': 4417, 'max_supply': 9945, 'infinite_supply': None, 'last_updated': '2025-01-02T14:23:45.001Z', 'date_added': '2025-01-02T14:23:45.001Z', 'tags': ['7bts6urwb9o', 'ue0ccxpu5c', 'cz60t4zcr6n', 'rwbvpjglle', '6xvldxsgt1u', '8egx3703u33', 'ch6etab4617', '41kmvkpz3js', 'sbrfq48qgv', '2jwtazzaawt'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.13205086929979437, 'volume_24h': 3434, 'volume_change_24h': 0.7606289035526381, 'percent_change_1h': 0.8139207684437912, 'percent_change_24h': 0.2751572525979926, 'percent_change_7d': 0.10359043472456775, 'market_cap': 0.30863023733782247, 'market_cap_dominance': 8072, 'fully_diluted_market_cap': 0.24170979684702254, 'last_updated': '2025-01-02T14:23:45.001Z'}}}, {'id': 5899, 'name': 'pnaqt49ezw8', 'symbol': 'jdaml678x3i', 'slug': 'mvsha58u5s', 'cmc_rank': 8086, 'num_market_pairs': 1886, 'circulating_supply': 7831, 'total_supply': 1325, 'max_supply': 3875, 'infinite_supply': None, 'last_updated': '2025-01-02T14:23:45.001Z', 'date_added': '2025-01-02T14:23:45.001Z', 'tags': ['d7x5af2j9cc', 'bv5pverpgrb', '4onq613iv0n', 'cz7h5vfqqde', 'cxm086zmil', 'asjrm1dat6w', '72y33bjbkox', 'b07wlqarn5m', '2qwx2mu3e18', 'ckksjrpyd5n'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.41119195692550603, 'volume_24h': 1862, 'volume_change_24h': 0.6165003605316506, 'percent_change_1h': 0.7317442936661145, 'percent_change_24h': 0.5752029073210254, 'percent_change_7d': 0.4825359972101775, 'market_cap': 0.5508113381338935, 'market_cap_dominance': 1708, 'fully_diluted_market_cap': 0.9278475396550099, 'last_updated': '2025-01-02T14:23:45.001Z'}}}, {'id': 3517, 'name': 'vuh2x9nwu5', 'symbol ...

# %% [markdown]
# - Testing the API connection in production environment with my own user credentials

# %%
# defining the base url that will be useful on any later calls
base_url= os.environ.get('COIN_MARKET_API_BASE_URL')

# defining the access_token regarding my own user in the subscribed platform
access_token= os.environ.get('COIN_MARKET_API_ACCESS_TOKEN')

# api call parameters (here using the same as above)
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}

# redefining the headers variable according to documentation reference, but with the appropriate pointer to my user access token
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': access_token,
}

# doing the api call attempt
test_url= base_url+'/v1/cryptocurrency/listings/latest'
try:
    response = r.get(test_url, params= parameters, headers= headers)
    data= json.loads(response.text)
    #print(data) 
    print(response.status_code)
    print(response.reason)
except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)
# Out:
# 200
# OK

# %%
data
# Out:
# {'status': {'timestamp': '2025-01-02T14:23:46.431Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 81,
#   'credit_count': 25,
#   'notice': None,
#   'total_count': 10492},
#  'data': [{'id': 1,
#    'name': 'Bitcoin',
#    'symbol': 'BTC',
#    'slug': 'bitcoin',
#    'num_market_pairs': 11853,
#    'date_added': '2010-07-13T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'sha-256',
#     'store-of-value',
#     'state-channel',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'binance-labs-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'dcg-portfolio',
#     'dragonfly-capital-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'framework-ventures-portfolio',
#     'galaxy-digital-portfolio',
#     'huobi-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     '1confirmation-portfolio',
#     'winklevoss-capital-portfolio',
#     'usv-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'multicoin-capital-portfolio',
#     'paradigm-portfolio',
#     'bitcoin-ecosystem',
#     'ftx-bankruptcy-estate',
#     '2017-2018-alt-season'],
#    'max_supply': 21000000,
#    'circulating_supply': 19804618,
#    'total_supply': 19804618,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 1,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 96568.43183846063,
#      'volume_24h': 33908108143.97013,
#      'volume_change_24h': 0.9131,
#      'percent_change_1h': -0.02600308,
#      'percent_change_24h': 3.15823365,
#      'percent_change_7d': 1.15227002,
#      'percent_change_30d': 2.27390237,
#      'percent_change_60d': 41.44343707,
#      'percent_change_90d': 56.2670146,
#      'market_cap': 1912500903419.7505,
#      'market_cap_dominance': 56.1331,
#      'fully_diluted_market_cap': 2027937068607.67,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'num_market_pairs': 9771,
#    'date_added': '2015-08-07T00:00:00.000Z',
#    'tags': ['pos',
#     'smart-contracts',
#     'ethereum-ecosystem',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'binance-labs-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'dcg-portfolio',
#     'dragonfly-capital-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'framework-ventures-portfolio',
#     'hashkey-capital-portfolio',
#     'kenetic-capital-portfolio',
#     'huobi-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     '1confirmation-portfolio',
#     'winklevoss-capital-portfolio',
#     'usv-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'multicoin-capital-portfolio',
#     'paradigm-portfolio',
#     'layer-1',
#     'ftx-bankruptcy-estate'],
#    'max_supply': None,
#    'circulating_supply': 120475207.62736247,
#    'total_supply': 120475207.62736247,
#    'infinite_supply': True,
#    'platform': None,
#    'cmc_rank': 2,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 3467.2242461574,
#      'volume_24h': 18824803614.42575,
#      'volume_change_24h': 4.7883,
#      'percent_change_1h': -0.05784864,
#      'percent_change_24h': 4.04368825,
#      'percent_change_7d': 3.61970379,
#      'percent_change_30d': -2.95301508,
#      'percent_change_60d': 41.8060962,
#      'percent_change_90d': 45.23245364,
#      'market_cap': 417714560946.4381,
#      'market_cap_dominance': 12.2638,
#      'fully_diluted_market_cap': 417714560946.44,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 52,
#    'name': 'XRP',
#    'symbol': 'XRP',
#    'slug': 'xrp',
#    'num_market_pairs': 1491,
#    'date_added': '2013-08-04T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'enterprise-solutions',
#     'arrington-xrp-capital-portfolio',
#     'galaxy-digital-portfolio',
#     'a16z-portfolio',
#     'pantera-capital-portfolio',
#     'ftx-bankruptcy-estate',
#     '2017-2018-alt-season'],
#    'max_supply': 100000000000,
#    'circulating_supply': 57410227039,
#    'total_supply': 99986740020,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 3,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 2.400849175398279,
#      'volume_24h': 10811506903.539955,
#      'volume_change_24h': 143.2964,
#      'percent_change_1h': -0.24032837,
#      'percent_change_24h': 11.03497107,
#      'percent_change_7d': 10.88571383,
#      'percent_change_30d': -7.31804193,
#      'percent_change_60d': 381.0676859,
#      'percent_change_90d': 356.58484673,
#      'market_cap': 137833296246.01114,
#      'market_cap_dominance': 4.0467,
#      'fully_diluted_market_cap': 240084917539.83,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 825,
#    'name': 'Tether USDt',
#    'symbol': 'USDT',
#    'slug': 'tether',
#    'num_market_pairs': 111039,
#    'date_added': '2015-02-25T00:00:00.000Z',
#    'tags': ['stablecoin',
#     'asset-backed-stablecoin',
#     'avalanche-ecosystem',
#     'solana-ecosystem',
#     'arbitrum-ecosytem',
#     'moonriver-ecosystem',
#     'injective-ecosystem',
#     'bnb-chain',
#     'usd-stablecoin',
#     'optimism-ecosystem',
#     'fiat-stablecoin'],
#    'max_supply': None,
#    'circulating_supply': 137432664160.48042,
#    'total_supply': 141440125251.01395,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xdac17f958d2ee523a2206206994597c13d831ec7'},
#    'infinite_supply': True,
#    'cmc_rank': 4,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 0.9989326992937512,
#      'volume_24h': 93899866004.0818,
#      'volume_change_24h': 25.0072,
#      'percent_change_1h': -0.00563428,
#      'percent_change_24h': 0.08444662,
#      'percent_change_7d': -0.00827816,
#      'percent_change_30d': -0.11573324,
#      'percent_change_60d': -0.07955847,
#      'percent_change_90d': -0.07649691,
#      'market_cap': 137285982180.96028,
#      'market_cap_dominance': 4.0307,
#      'fully_diluted_market_cap': 141289166105.44,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 1839,
#    'name': 'BNB',
#    'symbol': 'BNB',
#    'slug': 'bnb',
#    'num_market_pairs': 2322,
#    'date_added': '2017-07-25T00:00:00.000Z',
#    'tags': ['marketplace',
#     'centralized-exchange',
#     'payments',
#     'smart-contracts',
#     'alameda-research-portfolio',
#     'multicoin-capital-portfolio',
#     'bnb-chain',
#     'layer-1',
#     'alleged-sec-securities',
#     'celsius-bankruptcy-estate'],
#    'max_supply': None,
#    'circulating_supply': 144006930.19,
#    'total_supply': 144006930.19,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 5,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 711.0327637561114,
#      'volume_24h': 1777415323.2279022,
#      'volume_change_24h': -17.9755,
#      'percent_change_1h': -0.08621945,
#      'percent_change_24h': 0.44324627,
#      'percent_change_7d': 3.05729561,
#      'percent_change_30d': 11.06327079,
#      'percent_change_60d': 27.90506058,
#      'percent_change_90d': 28.44252663,
#      'market_cap': 102393645573.0291,
#      'market_cap_dominance': 3.0062,
#      'fully_diluted_market_cap': 102393645573.03,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 5426,
#    'name': 'Solana',
#    'symbol': 'SOL',
#    'slug': 'solana',
#    'num_market_pairs': 817,
#    'date_added': '2020-04-10T00:00:00.000Z',
#    'tags': ['pos',
#     'platform',
#     'solana-ecosystem',
#     'cms-holdings-portfolio',
#     'kenetic-capital-portfolio',
#     'alameda-research-portfolio',
#     'multicoin-capital-portfolio',
#     'okx-ventures-portfolio',
#     'layer-1',
#     'ftx-bankruptcy-estate',
#     'alleged-sec-securities',
#     'cmc-crypto-awards-2024'],
#    'max_supply': None,
#    'circulating_supply': 482816450.1131605,
#    'total_supply': 591340427.2860707,
#    'infinite_supply': True,
#    'platform': None,
#    'cmc_rank': 6,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 208.11573222855114,
#      'volume_24h': 3846011025.4451756,
#      'volume_change_24h': 34.1339,
#      'percent_change_1h': 0.01336608,
#      'percent_change_24h': 9.76535284,
#      'percent_change_7d': 10.37217298,
#      'percent_change_30d': -6.43125007,
#      'percent_change_60d': 28.19793693,
#      'percent_change_90d': 47.28242798,
#      'market_cap': 100481699047.29013,
#      'market_cap_dominance': 2.9501,
#      'fully_diluted_market_cap': 123067246020.98,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 74,
#    'name': 'Dogecoin',
#    'symbol': 'DOGE',
#    'slug': 'dogecoin',
#    'num_market_pairs': 1136,
#    'date_added': '2013-12-15T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'scrypt',
#     'medium-of-exchange',
#     'memes',
#     'payments',
#     'doggone-doggerel',
#     'bnb-chain',
#     'ftx-bankruptcy-estate'],
#    'max_supply': None,
#    'circulating_supply': 147456226383.70523,
#    'total_supply': 147456226383.70523,
#    'infinite_supply': True,
#    'platform': None,
#    'cmc_rank': 7,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 0.33947701003062114,
#      'volume_24h': 3015145507.4600444,
#      'volume_change_24h': 68.6347,
#      'percent_change_1h': -0.52369887,
#      'percent_change_24h': 7.07600781,
#      'percent_change_7d': 7.88674305,
#      'percent_change_30d': -16.17307048,
#      'percent_change_60d': 129.9490671,
#      'percent_change_90d': 212.22570602,
#      'market_cap': 50057998843.13864,
#      'market_cap_dominance': 1.4697,
#      'fully_diluted_market_cap': 50057998843.14,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 3408,
#    'name': 'USDC',
#    'symbol': 'USDC',
#    'slug': 'usd-coin',
#    'num_market_pairs': 24349,
#    'date_added': '2018-10-08T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'stablecoin',
#     'asset-backed-stablecoin',
#     'coinbase-ventures-portfolio',
#     'solana-ecosystem',
#     'hedera-hashgraph-ecosystem',
#     'arbitrum-ecosytem',
#     'moonriver-ecosystem',
#     'bnb-chain',
#     'usd-stablecoin',
#     'optimism-ecosystem',
#     'base-ecosystem',
#     'fiat-stablecoin'],
#    'max_supply': None,
#    'circulating_supply': 43791982268.942604,
#    'total_supply': 43791982268.942604,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#    'infinite_supply': False,
#    'cmc_rank': 8,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 0.9999311408777084,
#      'volume_24h': 6894611233.035426,
#      'volume_change_24h': 32.0393,
#      'percent_change_1h': -0.01345465,
#      'percent_change_24h': -0.01131513,
#      'percent_change_7d': -0.01058091,
#      'percent_change_30d': -0.00852871,
#      'percent_change_60d': -0.01755483,
#      'percent_change_90d': -0.00212167,
#      'market_cap': 43788966791.480156,
#      'market_cap_dominance': 1.2852,
#      'fully_diluted_market_cap': 43788966791.48,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 2010,
#    'name': 'Cardano',
#    'symbol': 'ADA',
#    'slug': 'cardano',
#    'num_market_pairs': 1425,
#    'date_added': '2017-10-01T00:00:00.000Z',
#    'tags': ['dpos',
#     'pos',
#     'platform',
#     'research',
#     'smart-contracts',
#     'staking',
#     'cardano-ecosystem',
#     'cardano',
#     'layer-1',
#     'alleged-sec-securities',
#     '2017-2018-alt-season'],
#    'max_supply': 45000000000,
#    'circulating_supply': 35139781273.91349,
#    'total_supply': 44995129917.33332,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 9,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 0.9654628340065583,
#      'volume_24h': 1519204177.207781,
#      'volume_change_24h': 159.357,
#      'percent_change_1h': -0.41860795,
#      'percent_change_24h': 11.75844444,
#      'percent_change_7d': 11.42774854,
#      'percent_change_30d': -21.01150382,
#      'percent_change_60d': 188.54528779,
#      'percent_change_90d': 173.18807614,
#      'market_cap': 33926152815.083107,
#      'market_cap_dominance': 0.996,
#      'fully_diluted_market_cap': 43445827530.3,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 1958,
#    'name': 'TRON',
#    'symbol': 'TRX',
#    'slug': 'tron',
#    'num_market_pairs': 1094,
#    'date_added': '2017-09-13T00:00:00.000Z',
#    'tags': ['media',
#     'payments',
#     'tron-ecosystem',
#     'layer-1',
#     'dwf-labs-portfolio',
#     'alleged-sec-securities',
#     '2017-2018-alt-season'],
#    'max_supply': None,
#    'circulating_supply': 86196192223.7874,
#    'total_supply': 86196200077.00716,
#    'infinite_supply': True,
#    'platform': None,
#    'cmc_rank': 10,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 0.26384130751756174,
#      'volume_24h': 703714783.8265997,
#      'volume_change_24h': 59.5752,
#      'percent_change_1h': 0.50821382,
#      'percent_change_24h': 4.07266511,
#      'percent_change_7d': 5.17754301,
#      'percent_change_30d': 13.09997059,
#      'percent_change_60d': 61.32794519,
#      'percent_change_90d': 67.63098417,
#      'market_cap': 22742116059.359154,
#      'market_cap_dominance': 0.6677,
#      'fully_diluted_market_cap': 22742118131.36,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 5805,
#    'name': 'Avalanche',
#    'symbol': 'AVAX',
#    'slug': 'avalanche',
#    'num_market_pairs': 831,
#    'date_added': '2020-07-13T00:00:00.000Z',
#    'tags': ['defi',
#     'smart-contracts',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'avalanche-ecosystem',
#     'cms-holdings-portfolio',
#     'dragonfly-capital-portfolio',
#     'real-world-assets',
#     'layer-1'],
#    'max_supply': 715748719,
#    'circulating_supply': 409921285.45371157,
#    'total_supply': 448257585.45371157,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 11,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 40.023537735046645,
#      'volume_24h': 510175967.72619516,
#      'volume_change_24h': 83.5203,
#      'percent_change_1h': 0.22323799,
#      'percent_change_24h': 11.75656163,
#      'percent_change_7d': 6.51103264,
#      'percent_change_30d': -22.16249625,
#      'percent_change_60d': 73.8118429,
#      'percent_change_90d': 55.48569237,
#      'market_cap': 16406500036.755453,
#      'market_cap_dominance': 0.4815,
#      'fully_diluted_market_cap': 28646795863.71,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 1975,
#    'name': 'Chainlink',
#    'symbol': 'LINK',
#    'slug': 'chainlink',
#    'num_market_pairs': 1909,
#    'date_added': '2017-09-20T00:00:00.000Z',
#    'tags': ['platform',
#     'defi',
#     'oracles',
#     'smart-contracts',
#     'substrate',
#     'polkadot',
#     'avalanche-ecosystem',
#     'solana-ecosystem',
#     'framework-ventures-portfolio',
#     'polygon-ecosystem',
#     'fantom-ecosystem',
#     'cardano-ecosystem',
#     'web3',
#     'near-protocol-ecosystem',
#     'arbitrum-ecosytem',
#     'cardano',
#     'injective-ecosystem',
#     'optimism-ecosystem',
#     'real-world-assets',
#     'celsius-bankruptcy-estate'],
#    'max_supply': None,
#    'circulating_supply': 638099970.4527867,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x514910771af9ca656af840dff83e8264ecf986ca'},
#    'infinite_supply': False,
#    'cmc_rank': 12,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 22.60279297338878,
#      'volume_24h': 974751204.9695836,
#      'volume_change_24h': 79.4718,
#      'percent_change_1h': 0.37551949,
#      'percent_change_24h': 12.15582765,
#      'percent_change_7d': -0.67640169,
#      'percent_change_30d': -5.69236962,
#      'percent_change_60d': 109.27818759,
#      'percent_change_90d': 105.02770362,
#      'market_cap': 14422841528.469835,
#      'market_cap_dominance': 0.4234,
#      'fully_diluted_market_cap': 22602792973.39,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 11419,
#    'name': 'Toncoin',
#    'symbol': 'TON',
#    'slug': 'toncoin',
#    'num_market_pairs': 644,
#    'date_added': '2021-08-26T13:40:22.000Z',
#    'tags': ['pos',
#     'layer-1',
#     'ftx-bankruptcy-estate',
#     'dwf-labs-portfolio',
#     'toncoin-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 2539203002.174552,
#    'total_supply': 5118883389.662005,
#    'infinite_supply': True,
#    'platform': None,
#    'cmc_rank': 13,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 5.636176589399259,
#      'volume_24h': 163396315.2774979,
#      'volume_change_24h': 10.0623,
#      'percent_change_1h': -0.26700415,
#      'percent_change_24h': 3.99736308,
#      'percent_change_7d': -1.62412119,
#      'percent_change_30d': -14.10334927,
#      'percent_change_60d': 18.84684884,
#      'percent_change_90d': 4.90853445,
#      'market_cap': 14311396516.588526,
#      'market_cap_dominance': 0.4202,
#      'fully_diluted_market_cap': 28850930724.68,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 5994,
#    'name': 'Shiba Inu',
#    'symbol': 'SHIB',
#    'slug': 'shiba-inu',
#    'num_market_pairs': 923,
#    'date_added': '2020-08-01T00:00:00.000Z',
#    'tags': ['memes', 'ethereum-ecosystem', 'doggone-doggerel'],
#    'max_supply': None,
#    'circulating_supply': 589255404974329.6,
#    'total_supply': 589508505866384.1,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'},
#    'infinite_supply': False,
#    'cmc_rank': 14,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 2.2720033883306848e-05,
#      'volume_24h': 491848385.3732796,
#      'volume_change_24h': 46.7864,
#      'percent_change_1h': -0.25381068,
#      'percent_change_24h': 8.05697137,
#      'percent_change_7d': 5.16418157,
#      'percent_change_30d': -19.63683509,
#      'percent_change_60d': 36.61820986,
#      'percent_change_90d': 28.88565067,
#      'market_cap': 13387902766.938467,
#      'market_cap_dominance': 0.3931,
#      'fully_diluted_market_cap': 13393653227.78,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 20947,
#    'name': 'Sui',
#    'symbol': 'SUI',
#    'slug': 'sui',
#    'num_market_pairs': 500,
#    'date_added': '2022-07-12T08:03:11.000Z',
#    'tags': ['binance-launchpool',
#     'coinbase-ventures-portfolio',
#     'binance-labs-portfolio',
#     'electric-capital-portfolio',
#     'a16z-portfolio',
#     'sui-ecosystem',
#     'layer-1',
#     'move-vm'],
#    'max_supply': 10000000000,
#    'circulating_supply': 3009569341.533888,
#    'total_supply': 10000000000,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 15,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 4.406765549494507,
#      'volume_24h': 911168776.5282372,
#      'volume_change_24h': 18.4246,
#      'percent_change_1h': -0.19593197,
#      'percent_change_24h': 6.30656102,
#      'percent_change_7d': 4.02787315,
#      'percent_change_30d': 18.17218451,
#      'percent_change_60d': 139.53724127,
#      'percent_change_90d': 146.87797671,
#      'market_cap': 13262466493.086405,
#      'market_cap_dominance': 0.3894,
#      'fully_diluted_market_cap': 44067655494.95,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 512,
#    'name': 'Stellar',
#    'symbol': 'XLM',
#    'slug': 'stellar',
#    'num_market_pairs': 658,
#    'date_added': '2014-08-05T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'enterprise-solutions',
#     'decentralized-exchange-dex-token',
#     'smart-contracts',
#     'hashkey-capital-portfolio',
#     '2017-2018-alt-season'],
#    'max_supply': 50001806812,
#    'circulating_supply': 30280002953.022472,
#    'total_supply': 50001786906.902374,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 16,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 0.430953101763317,
#      'volume_24h': 2671214110.221797,
#      'volume_change_24h': 257.5249,
#      'percent_change_1h': 0.72569535,
#      'percent_change_24h': 16.37865636,
#      'percent_change_7d': 20.79845649,
#      'percent_change_30d': -17.45956863,
#      'percent_change_60d': 377.3906714,
#      'percent_change_90d': 375.0654073,
#      'market_cap': 13049261194.007433,
#      'market_cap_dominance': 0.3831,
#      'fully_diluted_market_cap': 21548433739.4,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 4642,
#    'name': 'Hedera',
#    'symbol': 'HBAR',
#    'slug': 'hedera',
#    'num_market_pairs': 305,
#    'date_added': '2019-09-17T00:00:00.000Z',
#    'tags': ['dag',
#     'marketplace',
#     'enterprise-solutions',
#     'defi',
#     'payments',
#     'dcg-portfolio',
#     'hedera-hashgraph-ecosystem',
#     'real-world-assets',
#     'layer-1'],
#    'max_supply': 50000000000,
#    'circulating_supply': 38252162538.58472,
#    'total_supply': 50000000000,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 17,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 0.29462406307931444,
#      'volume_24h': 1274268904.9253688,
#      'volume_change_24h': 190.7364,
#      'percent_change_1h': 0.21122866,
#      'percent_change_24h': 8.97554326,
#      'percent_change_7d': 2.35643694,
#      'percent_change_30d': -8.32231324,
#      'percent_change_60d': 594.59082794,
#      'percent_change_90d': 455.78423863,
#      'market_cap': 11270007548.688171,
#      'market_cap_dominance': 0.3309,
#      'fully_diluted_market_cap': 14731203153.97,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 6636,
#    'name': 'Polkadot',
#    'symbol': 'DOT',
#    'slug': 'polkadot-new',
#    'num_market_pairs': 855,
#    'date_added': '2020-08-19T00:00:00.000Z',
#    'tags': ['substrate',
#     'polkadot',
#     'polkadot-ecosystem',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'arrington-xrp-capital-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'coinfund-portfolio',
#     'fabric-ventures-portfolio',
#     'fenbushi-capital-portfolio',
#     'hashkey-capital-portfolio',
#     'kenetic-capital-portfolio',
#     '1confirmation-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'exnetwork-capital-portfolio',
#     'web3',
#     'spartan-group',
#     'layer-1'],
#    'max_supply': None,
#    'circulating_supply': 1534647761.3257334,
#    'total_supply': 1534647761.3257334,
#    'infinite_supply': True,
#    'platform': None,
#    'cmc_rank': 18,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 7.263413305798938,
#      'volume_24h': 314218904.83915675,
#      'volume_change_24h': 83.2404,
#      'percent_change_1h': 0.00931545,
#      'percent_change_24h': 8.62588791,
#      'percent_change_7d': 4.38038777,
#      'percent_change_30d': -25.20401363,
#      'percent_change_60d': 95.02620488,
#      'percent_change_90d': 73.7396255,
#      'market_cap': 11146780969.327885,
#      'market_cap_dominance': 0.3273,
#      'fully_diluted_market_cap': 11146780969.33,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 1831,
#    'name': 'Bitcoin Cash',
#    'symbol': 'BCH',
#    'slug': 'bitcoin-cash',
#    'num_market_pairs': 962,
#    'date_added': '2017-07-23T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'sha-256',
#     'marketplace',
#     'medium-of-exchange',
#     'store-of-value',
#     'enterprise-solutions',
#     'payments',
#     'bitcoin-ecosystem',
#     'layer-1',
#     '2017-2018-alt-season'],
#    'max_supply': 21000000,
#    'circulating_supply': 19810250,
#    'total_supply': 19810250,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 19,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 463.3798278979356,
#      'volume_24h': 352008329.5609987,
#      'volume_change_24h': 51.8046,
#      'percent_change_1h': 0.12293401,
#      'percent_change_24h': 5.8523005,
#      'percent_change_7d': 5.89933821,
#      'percent_change_30d': -15.00835824,
#      'percent_change_60d': 36.98628714,
#      'percent_change_90d': 43.12007087,
#      'market_cap': 9179670235.61508,
#      'market_cap_dominance': 0.2695,
#      'fully_diluted_market_cap': 9730976385.86,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 24478,
#    'name': 'Pepe',
#    'symbol': 'PEPE',
#    'slug': 'pepe',
#    'num_market_pairs': 500,
#    'date_added': '2023-04-17T06:18:08.000Z',
#    'tags': ['memes'],
#    'max_supply': 420690000000000,
#    'circulating_supply': 420689899999994.8,
#    'total_supply': 420689899999994.8,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x6982508145454ce325ddbe47a25d4ec3d2311933'},
#    'infinite_supply': False,
#    'cmc_rank': 20,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 2.0883580242947247e-05,
#      'volume_24h': 2231376811.946417,
#      'volume_change_24h': -30.7033,
#      'percent_change_1h': 0.01972304,
#      'percent_change_24h': 7.86806778,
#      'percent_change_7d': 20.85556338,
#      'percent_change_30d': 5.49160133,
#      'percent_change_60d': 155.74376108,
#      'percent_change_90d': 126.23412678,
#      'market_cap': 8785511284.047344,
#      'market_cap_dominance': 0.2579,
#      'fully_diluted_market_cap': 8785513372.41,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 7083,
#    'name': 'Uniswap',
#    'symbol': 'UNI',
#    'slug': 'uniswap',
#    'num_market_pairs': 1152,
#    'date_added': '2020-09-17T00:00:00.000Z',
#    'tags': ['decentralized-exchange-dex-token',
#     'defi',
#     'dao',
#     'yield-farming',
#     'amm',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'governance',
#     'blockchain-capital-portfolio',
#     'defiance-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     'pantera-capital-portfolio',
#     'parafi-capital',
#     'paradigm-portfolio',
#     'arbitrum-ecosytem',
#     'injective-ecosystem',
#     'optimism-ecosystem',
#     'cmc-crypto-awards-2024'],
#    'max_supply': None,
#    'circulating_supply': 600483073.71,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x1f9840a85d5af5bf1d1762f925bdaddc4201f984'},
#    'infinite_supply': False,
#    'cmc_rank': 21,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 14.36551383248641,
#      'volume_24h': 366266137.5426178,
#      'volume_change_24h': 26.4854,
#      'percent_change_1h': 0.55617,
#      'percent_change_24h': 8.11882875,
#      'percent_change_7d': 11.07992112,
#      'percent_change_30d': 3.13759563,
#      'percent_change_60d': 102.98120415,
#      'percent_change_90d': 114.12027475,
#      'market_cap': 8626247901.554962,
#      'market_cap_dominance': 0.2533,
#      'fully_diluted_market_cap': 14365513832.49,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 3957,
#    'name': 'UNUS SED LEO',
#    'symbol': 'LEO',
#    'slug': 'unus-sed-leo',
#    'num_market_pairs': 56,
#    'date_added': '2019-05-21T00:00:00.000Z',
#    'tags': ['marketplace',
#     'centralized-exchange',
#     'discount-token',
#     'payments',
#     'kenetic-capital-portfolio',
#     'alameda-research-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 924398004.9,
#    'total_supply': 985239504,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3'},
#    'infinite_supply': False,
#    'cmc_rank': 22,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 9.080722840307951,
#      'volume_24h': 4467977.59646663,
#      'volume_change_24h': -22.5858,
#      'percent_change_1h': 0.23984097,
#      'percent_change_24h': 0.67834296,
#      'percent_change_7d': -1.00713982,
#      'percent_change_30d': 3.07995356,
#      'percent_change_60d': 50.24817834,
#      'percent_change_90d': 53.75547933,
#      'market_cap': 8394202076.630531,
#      'market_cap_dominance': 0.2465,
#      'fully_diluted_market_cap': 8946686867.15,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 32196,
#    'name': 'Hyperliquid',
#    'symbol': 'HYPE',
#    'slug': 'hyperliquid',
#    'num_market_pairs': 42,
#    'date_added': '2024-07-15T10:14:50.000Z',
#    'tags': ['decentralized-exchange-dex-token',
#     'derivatives',
#     'layer-1',
#     'hyperliquid-ecosystem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 333928180,
#    'total_supply': 999993930,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 23,
#    'self_reported_circulating_supply': 333931719,
#    'self_reported_market_cap': 8389297801.237822,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 25.122794044125595,
#      'volume_24h': 177853503.42108768,
#      'volume_change_24h': -10.9917,
#      'percent_change_1h': -0.47412914,
#      'percent_change_24h': 3.45594671,
#      'percent_change_7d': 0.33766531,
#      'percent_change_30d': 186.20893617,
#      'percent_change_60d': 685.01948989,
#      'percent_change_90d': 685.01948989,
#      'market_cap': 8389208891.6697,
#      'market_cap_dominance': 0.2463,
#      'fully_diluted_market_cap': 25122794044.13,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 2,
#    'name': 'Litecoin',
#    'symbol': 'LTC',
#    'slug': 'litecoin',
#    'num_market_pairs': 1296,
#    'date_added': '2013-04-28T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'scrypt',
#     'medium-of-exchange',
#     '2017-2018-alt-season'],
#    'max_supply': 84000000,
#    'circulating_supply': 75374943.30410936,
#    'total_supply': 84000000,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 24,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 107.37841233365276,
#      'volume_24h': 652202916.1430926,
#      'volume_change_24h': 33.5688,
#      'percent_change_1h': 1.08500627,
#      'percent_change_24h': 2.87595868,
#      'percent_change_7d': 4.51462434,
#      'percent_change_30d': -16.13976648,
#      'percent_change_60d': 60.12891318,
#      'percent_change_90d': 66.55484661,
#      'market_cap': 8093641741.734355,
#      'market_cap_dominance': 0.2376,
#      'fully_diluted_market_cap': 9019786636.03,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 11092,
#    'name': 'Bitget Token',
#    'symbol': 'BGB',
#    'slug': 'bitget-token-new',
#    'num_market_pairs': 27,
#    'date_added': '2021-07-29T00:00:00.000Z',
#    'tags': ['centralized-exchange'],
#    'max_supply': 2000000000,
#    'circulating_supply': 1200000000,
#    'total_supply': 1200000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x54D2252757e1672EEaD234D27B1270728fF90581'},
#    'infinite_supply': False,
#    'cmc_rank': 25,
#    'self_reported_circulating_supply': 1200000000,
#    'self_reported_market_cap': 7567253613.982203,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 6.306044678318502,
#      'volume_24h': 430381337.2459827,
#      'volume_change_24h': -38.8157,
#      'percent_change_1h': -2.28043898,
#      'percent_change_24h': 9.68993036,
#      'percent_change_7d': -19.06731827,
#      'percent_change_30d': 302.03053534,
#      'percent_change_60d': 465.49034794,
#      'percent_change_90d': 522.75032211,
#      'market_cap': 7567253613.982203,
#      'market_cap_dominance': 0.2222,
#      'fully_diluted_market_cap': 12612089356.64,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 6535,
#    'name': 'NEAR Protocol',
#    'symbol': 'NEAR',
#    'slug': 'near-protocol',
#    'num_market_pairs': 479,
#    'date_added': '2020-08-11T00:00:00.000Z',
#    'tags': ['platform',
#     'ai-big-data',
#     'staking',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'arrington-xrp-capital-portfolio',
#     'coinfund-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'kenetic-capital-portfolio',
#     'near-protocol-ecosystem',
#     'cross-chain',
#     'injective-ecosystem',
#     'circle-ventures-portfolio',
#     'layer-1',
#     'alleged-sec-securities',
#     'account-abstraction',
#     'data-availability'],
#    'max_supply': None,
#    'circulating_supply': 1167950818,
#    'total_supply': 1228218386,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 26,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 5.485481896567315,
#      'volume_24h': 314034456.43260235,
#      'volume_change_24h': 39.1442,
#      'percent_change_1h': 0.06015484,
#      'percent_change_24h': 8.72799899,
#      'percent_change_7d': 8.30117823,
#      'percent_change_30d': -22.84615015,
#      'percent_change_60d': 51.16335694,
#      'percent_change_90d': 15.06905112,
#      'market_cap': 6406773068.219987,
#      'market_cap_dominance': 0.1881,
#      'fully_diluted_market_cap': 6737369721.43,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 29470,
#    'name': 'Ethena USDe',
#    'symbol': 'USDe',
#    'slug': 'ethena-usde',
#    'num_market_pairs': 98,
#    'date_added': '2024-02-20T11:05:01.000Z',
#    'tags': ['stablecoin',
#     'asset-backed-stablecoin',
#     'binance-labs-portfolio',
#     'dragonfly-capital-portfolio',
#     'usd-stablecoin',
#     'eigenlayer-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 5866210562.559972,
#    'total_supply': 5866210562.559972,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x4c9edd5852cd905f086c759e8383e09bff1e68b3'},
#    'infinite_supply': True,
#    'cmc_rank': 27,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 0.9977768701147476,
#      'volume_24h': 78087159.29773393,
#      'volume_change_24h': 88.7429,
#      'percent_change_1h': -0.00599148,
#      'percent_change_24h': 0.05536036,
#      'percent_change_7d': -0.06242129,
#      'percent_change_30d': -0.33882468,
#      'percent_change_60d': -0.30588364,
#      'percent_change_90d': -0.16179956,
#      'market_cap': 5853169214.545161,
#      'market_cap_dominance': 0.1718,
#      'fully_diluted_market_cap': 5853169214.55,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 4943,
#    'name': 'Dai',
#    'symbol': 'DAI',
#    'slug': 'multi-collateral-dai',
#    'num_market_pairs': 3434,
#    'date_added': '2019-11-22T00:00:00.000Z',
#    'tags': ['defi',
#     'stablecoin',
#     'asset-backed-stablecoin',
#     'ethereum-ecosystem',
#     'avalanche-ecosystem',
#     'polygon-ecosystem',
#     'fantom-ecosystem',
#     'arbitrum-ecosytem',
#     'harmony-ecosystem',
#     'moonriver-ecosystem',
#     'bnb-chain',
#     'usd-stablecoin',
#     'optimism-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 5365382702.664872,
#    'total_supply': 5365382702.664872,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x6b175474e89094c44da98b954eedeac495271d0f'},
#    'infinite_supply': True,
#    'cmc_rank': 28,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 0.999881093041231,
#      'volume_24h': 159985773.44686806,
#      'volume_change_24h': 20.8029,
#      'percent_change_1h': -0.00899651,
#      'percent_change_24h': 0.00761973,
#      'percent_change_7d': -0.0007112,
#      'percent_change_30d': 0.00532407,
#      'percent_change_60d': -0.00450329,
#      'percent_change_90d': -0.00180097,
#      'market_cap': 5364744721.325067,
#      'market_cap_dominance': 0.1575,
#      'fully_diluted_market_cap': 5364744721.33,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 21794,
#    'name': 'Aptos',
#    'symbol': 'APT',
#    'slug': 'aptos',
#    'num_market_pairs': 467,
#    'date_added': '2022-10-19T01:50:25.000Z',
#    'tags': ['binance-labs-portfolio',
#     'aptos-ecosystem',
#     'circle-ventures-portfolio',
#     'layer-1',
#     'ftx-bankruptcy-estate',
#     'move-vm'],
#    'max_supply': None,
#    'circulating_supply': 558014885.0200254,
#    'total_supply': 1133960530.3765192,
#    'infinite_supply': True,
#    'platform': None,
#    'cmc_rank': 29,
#    'self_reported_circulating_supply': 130000000,
#    'self_reported_market_cap': 1218189264.4772513,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 9.37068664982501,
#      'volume_24h': 217350672.4153578,
#      'volume_change_24h': 13.9422,
#      'percent_change_1h': 0.42344193,
#      'percent_change_24h': 8.33484505,
#      'percent_change_7d': 5.20908463,
#      'percent_change_30d': -32.69648997,
#      'percent_change_60d': 16.99849426,
#      'percent_change_90d': 4.9519929,
#      'market_cap': 5228982633.46079,
#      'market_cap_dominance': 0.1535,
#      'fully_diluted_market_cap': 10625988803.43,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 8916,
#    'name': 'Internet Computer',
#    'symbol': 'ICP',
#    'slug': 'internet-computer',
#    'num_market_pairs': 310,
#    'date_added': '2021-03-23T00:00:00.000Z',
#    'tags': ['platform',
#     'ai-big-data',
#     'smart-contracts',
#     'polychain-capital-portfolio',
#     'electric-capital-portfolio',
#     'fenbushi-capital-portfolio',
#     'hashkey-capital-portfolio',
#     'a16z-portfolio',
#     'multicoin-capital-portfolio',
#     'exnetwork-capital-portfolio',
#     'internet-computer-ecosystem',
#     'layer-1',
#     'alleged-sec-securities'],
#    'max_supply': None,
#    'circulating_supply': 478665234.5733537,
#    'total_supply': 528415227.2253934,
#    'infinite_supply': True,
#    'platform': None,
#    'cmc_rank': 30,
#    'self_reported_circulating_supply': 478665379.4194236,
#    'self_reported_market_cap': 5122783705.066606,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 10.702223150711388,
#      'volume_24h': 152774100.3340429,
#      'volume_change_24h': 26.9122,
#      'percent_change_1h': -0.27364008,
#      'percent_change_24h': 7.64372119,
#      'percent_change_7d': 3.11207594,
#      'percent_change_30d': -22.03921739,
#      'percent_change_60d': 51.05121058,
#      'percent_change_90d': 29.05445094,
#      'market_cap': 5122782154.891644,
#      'market_cap_dominance': 0.1504,
#      'fully_diluted_market_cap': 5655217678,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 7278,
#    'name': 'Aave',
#    'symbol': 'AAVE',
#    'slug': 'aave',
#    'num_market_pairs': 995,
#    'date_added': '2020-10-02T00:00:00.000Z',
#    'tags': ['defi',
#     'dao',
#     'yield-farming',
#     'three-arrows-capital-portfolio',
#     'governance',
#     'lending-borowing',
#     'blockchain-capital-portfolio',
#     'defiance-capital-portfolio',
#     'framework-ventures-portfolio',
#     'alameda-research-portfolio',
#     'pantera-capital-portfolio',
#     'parafi-capital',
#     'polygon-ecosystem',
#     'fantom-ecosystem',
#     'optimism-ecosystem',
#     'standard-crypto-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 15038187.49754226,
#    'total_supply': 16000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x7Fc66500c84A76Ad7e9c93437bFc5Ac33E2DDaE9'},
#    'infinite_supply': False,
#    'cmc_rank': 31,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': 0.24057726,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 335.27091668660273,
#      'volume_24h': 559124063.260388,
#      'volume_change_24h': 17.02,
#      'percent_change_1h': 0.98696182,
#      'percent_change_24h': 7.0133687,
#      'percent_change_7d': -0.4922777,
#      'percent_change_30d': 42.82683345,
#      'percent_change_60d': 151.57263679,
#      'percent_change_90d': 125.08885854,
#      'market_cap': 5041866907.606002,
#      'market_cap_dominance': 0.148,
#      'fully_diluted_market_cap': 5364334666.99,
#      'tvl': 20957371436.23785,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 29420,
#    'name': 'Virtuals Protocol',
#    'symbol': 'VIRTUAL',
#    'slug': 'virtual-protocol',
#    'num_market_pairs': 268,
#    'date_added': '2024-02-15T07:33:29.000Z',
#    'tags': ['ai-big-data',
#     'metaverse',
#     'generative-ai',
#     'base-ecosystem',
#     'ai-agents',
#     'virtuals-protocol-ecosystem',
#     'ai-agent-launchpad'],
#    'max_supply': 1000000000,
#    'circulating_supply': 1000000000,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x44ff8620b8cA30902395A7bD3F2407e1A091BF73'},
#    'infinite_supply': False,
#    'cmc_rank': 32,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 4.649009362785057,
#      'volume_24h': 612035115.2657995,
#      'volume_change_24h': 69.9381,
#      'percent_change_1h': -0.42987546,
#      'percent_change_24h': 19.07812846,
#      'percent_change_7d': 63.61734837,
#      'percent_change_30d': 212.29883726,
#      'percent_change_60d': 1175.92879274,
#      'percent_change_90d': 8850.23817677,
#      'market_cap': 4649009362.785057,
#      'market_cap_dominance': 0.1365,
#      'fully_diluted_market_cap': 4649009362.79,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 27075,
#    'name': 'Mantle',
#    'symbol': 'MNT',
#    'slug': 'mantle',
#    'num_market_pairs': 107,
#    'date_added': '2023-07-17T11:00:31.000Z',
#    'tags': ['ethereum-ecosystem', 'layer-2', 'dwf-labs-portfolio'],
#    'max_supply': 6219316795,
#    'circulating_supply': 3364694382.8368406,
#    'total_supply': 6219316794.99,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x3c3a81e81dc49a522a592e7622a7e711c06bf354'},
#    'infinite_supply': False,
#    'cmc_rank': 33,
#    'self_reported_circulating_supply': 3364694382.8368406,
#    'self_reported_market_cap': 4553984855.829617,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 1.3534616632819,
#      'volume_24h': 129514817.36836313,
#      'volume_change_24h': -7.8411,
#      'percent_change_1h': 3.10853813,
#      'percent_change_24h': 5.03125779,
#      'percent_change_7d': 15.25432331,
#      'percent_change_30d': 51.94808839,
#      'percent_change_60d': 142.69376813,
#      'percent_change_90d': 131.53617642,
#      'market_cap': 4553984855.829617,
#      'market_cap_dominance': 0.1337,
#      'fully_diluted_market_cap': 8417606853.84,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 28321,
#    'name': 'POL (ex-MATIC)',
#    'symbol': 'POL',
#    'slug': 'polygon-ecosystem-token',
#    'num_market_pairs': 415,
#    'date_added': '2023-10-30T14:43:57.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 8402201157.3833275,
#    'total_supply': 10333669277.937664,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x455e53cbb86018ac2b8092fdcd39d8444affc3f6'},
#    'infinite_supply': False,
#    'cmc_rank': 34,
#    'self_reported_circulating_supply': 62242397.94040099,
#    'self_reported_market_cap': 30629605.93076872,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 0.492101958541146,
#      'volume_24h': 179589873.21446812,
#      'volume_change_24h': 24.7564,
#      'percent_change_1h': 0.28612247,
#      'percent_change_24h': 8.01960318,
#      'percent_change_7d': 2.46300291,
#      'percent_change_30d': -29.58785,
#      'percent_change_60d': 63.70983069,
#      'percent_change_90d': 28.85326703,
#      'market_cap': 4134739645.6050196,
#      'market_cap_dominance': 0.1214,
#      'fully_diluted_market_cap': 5085218890.59,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 3635,
#    'name': 'Cronos',
#    'symbol': 'CRO',
#    'slug': 'cronos',
#    'num_market_pairs': 268,
#    'date_added': '2018-12-14T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'cosmos-ecosystem',
#     'centralized-exchange',
#     'mobile',
#     'payments',
#     'injective-ecosystem',
#     'layer-1'],
#    'max_supply': None,
#    'circulating_supply': 26571560696,
#    'total_supply': 30000000000,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 35,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 0.15249122497119996,
#      'volume_24h': 38307209.33031918,
#      'volume_change_24h': 26.0388,
#      'percent_change_1h': -0.16608292,
#      'percent_change_24h': 5.68072424,
#      'percent_change_7d': 1.1161551,
#      'percent_change_30d': -20.39137608,
#      'percent_change_60d': 114.3954668,
#      'percent_change_90d': 89.29052632,
#      'market_cap': 4051929839.9296308,
#      'market_cap_dominance': 0.119,
#      'fully_diluted_market_cap': 4574736749.14,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 1321,
#    'name': 'Ethereum Classic',
#    'symbol': 'ETC',
#    'slug': 'ethereum-classic',
#    'num_market_pairs': 586,
# ...
#    'tags': ['stablecoin',
#     'asset-backed-stablecoin',
#     'harmony-ecosystem',
#     'fiat-stablecoin'],
#    'max_supply': None,
#    'circulating_supply': 291132793120,
#    'total_supply': 291132793120,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x998FFE1E43fAcffb941dc337dD0468d52bA5b48A'},
#    'infinite_supply': True,
#    'cmc_rank': 988,
#    'self_reported_circulating_supply': 48743000000,
#    'self_reported_market_cap': 3006552.2541535012,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 6.168172361474471e-05,
#      'volume_24h': 4295.44282993,
#      'volume_change_24h': -63.2239,
#      'percent_change_1h': 0.00011798,
#      'percent_change_24h': 0.5869367,
#      'percent_change_7d': 0.67502273,
#      'percent_change_30d': -1.46491351,
#      'percent_change_60d': -2.26092933,
#      'percent_change_90d': -3.46232713,
#      'market_cap': 17957572.48041649,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 17957572.48,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 24594,
#    'name': 'BOB (ETH)',
#    'symbol': 'BOB',
#    'slug': 'bob1',
#    'num_market_pairs': 53,
#    'date_added': '2023-04-21T01:33:58.000Z',
#    'tags': ['memes'],
#    'max_supply': 690000000000,
#    'circulating_supply': 689127646403,
#    'total_supply': 689127646403,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x7D8146cf21e8D7cbe46054e01588207b51198729'},
#    'infinite_supply': False,
#    'cmc_rank': 989,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 2.5961000345567543e-05,
#      'volume_24h': 2257206.48943022,
#      'volume_change_24h': 31.032,
#      'percent_change_1h': 0.26835299,
#      'percent_change_24h': 8.74434644,
#      'percent_change_7d': 13.95473787,
#      'percent_change_30d': -13.75952972,
#      'percent_change_60d': -12.93707333,
#      'percent_change_90d': -10.69039313,
#      'market_cap': 17890443.06640843,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 17913090.24,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 2763,
#    'name': 'Morpheus.Network',
#    'symbol': 'MNW',
#    'slug': 'morpheus-network',
#    'num_market_pairs': 40,
#    'date_added': '2018-05-22T00:00:00.000Z',
#    'tags': ['logistics', 'masternodes', 'payments'],
#    'max_supply': 47897218,
#    'circulating_supply': 47180013.8588,
#    'total_supply': 47897218,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xd3E4Ba569045546D09CF021ECC5dFe42b1d7f6E4'},
#    'infinite_supply': False,
#    'cmc_rank': 990,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 0.3760036637579169,
#      'volume_24h': 47134.49549825,
#      'volume_change_24h': -12.518,
#      'percent_change_1h': 2.84589951,
#      'percent_change_24h': 8.48262863,
#      'percent_change_7d': 0.37858204,
#      'percent_change_30d': -36.60758418,
#      'percent_change_60d': 47.76719324,
#      'percent_change_90d': -8.97346073,
#      'market_cap': 17739858.067058094,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 18009529.45,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 28348,
#    'name': 'MiraclePlay',
#    'symbol': 'MPT',
#    'slug': 'miracle-play',
#    'num_market_pairs': 10,
#    'date_added': '2023-11-03T09:18:19.000Z',
#    'tags': [],
#    'max_supply': 3000000000,
#    'circulating_supply': 769638518.6627901,
#    'total_supply': 900177377.4886799,
#    'platform': {'id': 3890,
#     'name': 'Polygon',
#     'symbol': 'MATIC',
#     'slug': 'polygon',
#     'token_address': '0x87d6F8eDECcbCcA766D2880D19b2C3777D322C22'},
#    'infinite_supply': False,
#    'cmc_rank': 991,
#    'self_reported_circulating_supply': 769772743.7173309,
#    'self_reported_market_cap': 17697758.358939037,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 0.02299088725001395,
#      'volume_24h': 4183243.50595722,
#      'volume_change_24h': 60.0209,
#      'percent_change_1h': -0.0411825,
#      'percent_change_24h': -0.90767927,
#      'percent_change_7d': -3.79229779,
#      'percent_change_30d': 3.67959353,
#      'percent_change_60d': -35.1188628,
#      'percent_change_90d': -37.8604893,
#      'market_cap': 17694672.405843962,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 68972661.75,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 14534,
#    'name': 'ParaSwap',
#    'symbol': 'PSP',
#    'slug': 'paraswap',
#    'num_market_pairs': 64,
#    'date_added': '2021-11-15T13:27:12.000Z',
#    'tags': ['decentralized-exchange-dex-token',
#     'defi',
#     'spartan-group',
#     'intent'],
#    'max_supply': 2000000000,
#    'circulating_supply': 744976909,
#    'total_supply': 1800000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xcafe001067cdef266afb7eb5a286dcfd277f3de5'},
#    'infinite_supply': False,
#    'cmc_rank': 992,
#    'self_reported_circulating_supply': 1533908455,
#    'self_reported_market_cap': 36312062.10037679,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 0.023672900414631846,
#      'volume_24h': 72698.44145732,
#      'volume_change_24h': -83.1446,
#      'percent_change_1h': 0.18560166,
#      'percent_change_24h': 1.97649386,
#      'percent_change_7d': -0.06474565,
#      'percent_change_30d': 6.3629993,
#      'percent_change_60d': 79.08744208,
#      'percent_change_90d': 75.40139407,
#      'market_cap': 17635764.17795725,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 47345800.83,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 2243,
#    'name': 'Dragonchain',
#    'symbol': 'DRGN',
#    'slug': 'dragonchain',
#    'num_market_pairs': 24,
#    'date_added': '2017-12-03T00:00:00.000Z',
#    'tags': ['platform', 'enterprise-solutions', 'alleged-sec-securities'],
#    'max_supply': 433494437,
#    'circulating_supply': 370772651.3625188,
#    'total_supply': 433494437,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x419c4db4b9e25d6db2ad9691ccb832c8d9fda05e'},
#    'infinite_supply': False,
#    'cmc_rank': 993,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 0.04732601423959255,
#      'volume_24h': 19279.01632718,
#      'volume_change_24h': 4.5493,
#      'percent_change_1h': 0.08958222,
#      'percent_change_24h': -4.34041502,
#      'percent_change_7d': -14.0868279,
#      'percent_change_30d': 124.73228026,
#      'percent_change_60d': 141.96305601,
#      'percent_change_90d': 103.4497325,
#      'market_cap': 17547191.778034046,
#      'market_cap_dominance': 0.0005,
#      'fully_diluted_market_cap': 20515563.9,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 22,
#    'name': 'Luckycoin',
#    'symbol': 'LKY',
#    'slug': 'luckycoin',
#    'num_market_pairs': 10,
#    'date_added': '2013-06-14T00:00:00.000Z',
#    'tags': ['mineable'],
#    'max_supply': 20000000,
#    'circulating_supply': 12070868,
#    'total_supply': 12070868,
#    'infinite_supply': False,
#    'platform': None,
#    'cmc_rank': 994,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 1.4455992605615424,
#      'volume_24h': 2043453.05087353,
#      'volume_change_24h': 1.4969,
#      'percent_change_1h': 8.29909888,
#      'percent_change_24h': 39.00302909,
#      'percent_change_7d': -40.80362723,
#      'percent_change_30d': -86.75893137,
#      'percent_change_60d': 12.6108338,
#      'percent_change_90d': 278.97224716,
#      'market_cap': 17449637.855135985,
#      'market_cap_dominance': 0.0005,
#      'fully_diluted_market_cap': 28911985.21,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 11206,
#    'name': 'Bloktopia',
#    'symbol': 'BLOK',
#    'slug': 'bloktopia',
#    'num_market_pairs': 97,
#    'date_added': '2021-08-09T00:00:00.000Z',
#    'tags': ['metaverse',
#     'polkafoundry-red-kite',
#     'bullperks-launchpad',
#     'animoca-brands-portfolio',
#     'oxbull'],
#    'max_supply': None,
#    'circulating_supply': 24792088581,
#    'total_supply': 117000000000,
#    'platform': {'id': 1839,
#     'name': 'BNB Smart Chain (BEP20)',
#     'symbol': 'BNB',
#     'slug': 'bnb',
#     'token_address': '0xA0d96fD642156FC7E964949642257b3572f10cD6'},
#    'infinite_supply': False,
#    'cmc_rank': 995,
#    'self_reported_circulating_supply': 13052608383,
#    'self_reported_market_cap': 9098218.00411711,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 0.0006970421341964743,
#      'volume_24h': 451178.55069016,
#      'volume_change_24h': 64.7032,
#      'percent_change_1h': -0.43634538,
#      'percent_change_24h': 3.36290692,
#      'percent_change_7d': -4.04990799,
#      'percent_change_30d': -25.97417706,
#      'percent_change_60d': 12.51737659,
#      'percent_change_90d': 1.36652452,
#      'market_cap': 17281130.335688278,
#      'market_cap_dominance': 0.0005,
#      'fully_diluted_market_cap': 81553929.7,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 23295,
#    'name': 'Veno Finance',
#    'symbol': 'VNO',
#    'slug': 'veno-finance-vno',
#    'num_market_pairs': 27,
#    'date_added': '2023-01-20T11:18:48.000Z',
#    'tags': [],
#    'max_supply': 2000000000,
#    'circulating_supply': 474514554,
#    'total_supply': 1844674055,
#    'platform': {'id': 3635,
#     'name': 'Cronos',
#     'symbol': 'CRO',
#     'slug': 'cronos',
#     'token_address': '0xdb7d0a1ec37de1de924f8e8adac6ed338d4404e9'},
#    'infinite_supply': False,
#    'cmc_rank': 996,
#    'self_reported_circulating_supply': 163476863.5,
#    'self_reported_market_cap': 5904358.362472079,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 0.0361173944499619,
#      'volume_24h': 9620.5520202,
#      'volume_change_24h': 110.4983,
#      'percent_change_1h': 0.36263377,
#      'percent_change_24h': 5.17967779,
#      'percent_change_7d': -0.74028108,
#      'percent_change_30d': 3.32155486,
#      'percent_change_60d': 90.2644263,
#      'percent_change_90d': 54.85578938,
#      'market_cap': 17138229.319065746,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 72234788.9,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 28443,
#    'name': 'Verified USD',
#    'symbol': 'USDV',
#    'slug': 'verified-usd',
#    'num_market_pairs': 141,
#    'date_added': '2023-11-17T11:56:26.000Z',
#    'tags': ['stablecoin',
#     'asset-backed-stablecoin',
#     'usd-stablecoin',
#     'fiat-stablecoin'],
#    'max_supply': None,
#    'circulating_supply': 17141815,
#    'total_supply': 17141815,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x0e573ce2736dd9637a0b21058352e1667925c7a8'},
#    'infinite_supply': False,
#    'cmc_rank': 997,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 0.996257197523387,
#      'volume_24h': 3255.8679168,
#      'volume_change_24h': 9.2272,
#      'percent_change_1h': 0.19122778,
#      'percent_change_24h': -0.12048539,
#      'percent_change_7d': 0.18656167,
#      'percent_change_30d': -0.31972227,
#      'percent_change_60d': -0.26731971,
#      'percent_change_90d': -0.00742524,
#      'market_cap': 17077656.57236436,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 17077656.57,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 11222,
#    'name': 'Nine Chronicles',
#    'symbol': 'WNCG',
#    'slug': 'wrapped-ncg',
#    'num_market_pairs': 44,
#    'date_added': '2021-08-11T00:00:00.000Z',
#    'tags': ['binance-labs-portfolio',
#     'animoca-brands-portfolio',
#     'skyvision-capital-portfolio',
#     'dwf-labs-portfolio'],
#    'max_supply': 1000000000,
#    'circulating_supply': 453682240.99,
#    'total_supply': 723789440,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xf203Ca1769ca8e9e8FE1DA9D147DB68B6c919817'},
#    'infinite_supply': False,
#    'cmc_rank': 998,
#    'self_reported_circulating_supply': 453671790.99,
#    'self_reported_market_cap': 17020540.853878636,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 0.03751730037421218,
#      'volume_24h': 480019.43694917,
#      'volume_change_24h': 44.4562,
#      'percent_change_1h': 0.10716736,
#      'percent_change_24h': 3.93281519,
#      'percent_change_7d': -2.82801828,
#      'percent_change_30d': -22.9513704,
#      'percent_change_60d': 2.76607693,
#      'percent_change_90d': -12.76849554,
#      'market_cap': 17020932.909667548,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 37517300.37,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 18345,
#    'name': 'QORPO WORLD',
#    'symbol': 'QORPO',
#    'slug': 'qorpo',
#    'num_market_pairs': 17,
#    'date_added': '2022-02-24T08:10:29.000Z',
#    'tags': ['collectibles-nfts',
#     'gaming',
#     'metaverse',
#     'play-to-earn',
#     'bullperks-launchpad',
#     'kommunitas-launchpad'],
#    'max_supply': 750000000,
#    'circulating_supply': 106155877.74333,
#    'total_supply': 749419877.75,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x22514fFb0d7232a56F0c24090E7B68f179FAA940'},
#    'infinite_supply': False,
#    'cmc_rank': 999,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 0.16033742489244127,
#      'volume_24h': 317420.08425086,
#      'volume_change_24h': 3.8721,
#      'percent_change_1h': 0.56957845,
#      'percent_change_24h': 2.57221729,
#      'percent_change_7d': -8.94156747,
#      'percent_change_30d': 21.40437623,
#      'percent_change_60d': 103.00843706,
#      'percent_change_90d': 17.84134088,
#      'market_cap': 17020760.074562352,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 120253068.67,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   {'id': 17072,
#    'name': 'Partisia Blockchain',
#    'symbol': 'MPC',
#    'slug': 'partisia-blockchain',
#    'num_market_pairs': 9,
#    'date_added': '2022-01-10T07:49:39.000Z',
#    'tags': ['enterprise-solutions'],
#    'max_supply': 1000000000,
#    'circulating_supply': 276651454.2714,
#    'total_supply': 553810781.8625,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x36a0e44c73e5a6a7727817377c0127f320a9456e'},
#    'infinite_supply': False,
#    'cmc_rank': 1000,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'tvl_ratio': None,
#    'last_updated': '2025-01-02T13:40:00.000Z',
#    'quote': {'USD': {'price': 0.0613983548690641,
#      'volume_24h': 222730.02819555,
#      'volume_change_24h': -15.7005,
#      'percent_change_1h': 3.05922964,
#      'percent_change_24h': 0.78212976,
#      'percent_change_7d': -14.7911383,
#      'percent_change_30d': -37.07906856,
#      'percent_change_60d': -36.59324492,
#      'percent_change_90d': -38.10242935,
#      'market_cap': 16985944.164398074,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 61398354.87,
#      'tvl': None,
#      'last_updated': '2025-01-02T13:40:00.000Z'}}},
#   ...]}

# %% [markdown]
# ### Exploring API endpoints and looking for useful content

# %% [markdown]
# #### 1) Cryptocurrency metadata
# - According to documentation, we could be doing the API call using parameters *slug* or *symbol*, but symbol would return every cryptocurrency associated to the value passed (for example, by searching for *BTC* we would find other cryptocurrencies beyond the usual bitcoin)

# %%
# defining the full query URL
metadata_url= base_url+'/v2/cryptocurrency/info'

# defining the appropriate parameters (I want to see basic information involving some of the main recent cryptocurrencies)
parameters= {
    'symbol': 'BTC,ETH,USDT,USDC,BNB,XRP,ADA,BUSD,SOL,DOT'
}
# Here we are using the symbol parameter in order to include 'Binance USD (BUSD)', 'Binance Coin (BNB)' and 'USD Coin (USDC)' in the search since their names have spaces and we could not specify them on slug argument. 

# But by doing it is important to emphasize a thing: using symbol parameter, the API will return to us any reference it has for such symbol stored in the endpoint we are calling (and it might not necessarily be a crypto). So we'll have to filter it later on

# making the call attempt
response= r.get(
    url= metadata_url
    ,params= parameters
    ,headers= headers
)

print(response.status_code)
print(response.reason)

# printing the entire response to take a look at the error message if there's a HTTP expection of type 4xx (i.e., user inconsistency)
if str(response.status_code)[0] == '4':
    print(response.json())
# Out:
# 200
# OK

# %%
# special treatment to handle all returned data and compile it on a single dataframe
crypto_symbols= ['BTC','ETH','USDT','USDC','BNB','XRP','ADA','BUSD','SOL','DOT']
df_data= []

for crypto in crypto_symbols:
    aux_df= pd.json_normalize(response.json()['data'][crypto])
    df_data.append(aux_df)

df= pd.concat(df_data, ignore_index= True)
df.head()
# Out:
# C:\Users\LUCAS\AppData\Local\Temp\ipykernel_18952\3920442243.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df= pd.concat(df_data, ignore_index= True)
#       id                         name symbol category  \
# 0      1                      Bitcoin    BTC     coin
# 1  34316  HarryPotterTrumpSonic100Inu    BTC    token
# 2  31652                       batcat    BTC    token
# 3  30938            Satoshi Pumpomoto    BTC    token
# 4  31469         Boost Trump Campaign    BTC    token
#
#                                          description  \
# 0  Bitcoin (BTC) is a cryptocurrency launched in ...
# 1  HarryPotterTrumpSonic100Inu (BTC) is a cryptoc...
# 2  batcat (BTC) is a cryptocurrency launched in 2...
# 3  Satoshi Pumpomoto (BTC) is a cryptocurrency la...
# 4  Boost Trump Campaign (BTC) is a cryptocurrency...
#
#                           slug  \
# 0                      bitcoin
# 1  harrypottertrumpsonic100inu
# 2                       batcat
# 3            satoshi-pumpomoto
# 4         boost-trump-campaign
#
#                                                 logo subreddit notice  \
# 0  https://s2.coinmarketcap.com/static/img/coins/...   bitcoin
# 1  https://s2.coinmarketcap.com/static/img/coins/...
# 2  https://s2.coinmarketcap.com/static/img/coins/...
# 3  https://s2.coinmarketcap.com/static/img/coins/...
# 4  https://s2.coinmarketcap.com/static/img/coins/...
#
#                                                 tags  ...  \
# 0  [mineable, pow, sha-256, store-of-value, state...  ...
# 1                                            [memes]  ...
# 2                          [memes, solana-ecosystem]  ...
# 3                                               None  ...
# 4                                               None  ...
#
#                                        urls.explorer  \
# 0  [https://blockchain.info/, https://live.blockc...
# 1  [https://etherscan.io/token/0x7099ab9e42fa7327...
# 2  [https://solscan.io/token/EtBc6gkCvsB9c6f5wSbw...
# 3  [https://solscan.io/token/6AGNtEgBE2jph1bWFdya...
# 4  [https://etherscan.io/token/0x300e0d87f8c95d90...
#
#                       urls.reddit                 urls.technical_doc  \
# 0  [https://reddit.com/r/bitcoin]  [https://bitcoin.org/bitcoin.pdf]
# 1                              []                                 []
# 2                              []                                 []
# 3                              []                                 []
# 4                              []                                 []
#
#                        urls.source_code urls.announcement  platform.id  \
# 0  [https://github.com/bitcoin/bitcoin]                []          NaN
# 1                                    []                []         1027
# 2                                    []                []         5426
# 3                                    []                []         5426
# 4                                    []                []         1027
#
#   platform.name platform.slug  platform.symbol  \
# 0           NaN           NaN              NaN
# 1      Ethereum      ethereum              ETH
# 2        Solana        solana              SOL
# 3        Solana        solana              SOL
# 4      Ethereum      ethereum              ETH
#
#                          platform.token_address
# 0                                           NaN
# 1    0x7099aB9E42Fa7327a6b15E0a0c120c3e50d11BeC
# 2  EtBc6gkCvsB9c6f5wSbwG8wPjRqXMB5euptK6bqG1R4X
# 3  6AGNtEgBE2jph1bWFdyaqsXJ762emaP9RE17kKxEsfiV
# 4    0x300e0d87f8c95d90cfe4b809baa3a6c90e83b850
#
# [5 rows x 37 columns]

# %%
df['category'].unique() # checking different categories of the extracted data
# Out:
# array(['coin', 'token'], dtype=object)

# %% [markdown]
# - As we previously mentioned, by filtering the query with the *symbol* argument we allow it to return to us different results that are not exclusively related to cryptos. We have te filter that

# %%
df= df[df['category'] == 'coin'] # applying filter on DataFrame

# %%
df['category'].unique() # checking the result
# Out:
# array(['coin'], dtype=object)

# %%
df.isna().sum() # verifying the quantity of null values inside the dataframe
# Out:
# id                                  0
# name                                0
# symbol                              0
# category                            0
# description                         0
# slug                                0
# logo                                0
# subreddit                           0
# notice                              0
# tags                                0
# tag-names                           0
# tag-groups                          0
# platform                            8
# date_added                          0
# twitter_username                    0
# is_hidden                           0
# date_launched                       5
# contract_address                    0
# self_reported_circulating_supply    8
# self_reported_tags                  6
# self_reported_market_cap            8
# infinite_supply                     0
# urls.website                        0
# urls.twitter                        0
# urls.message_board                  0
# urls.chat                           0
# urls.facebook                       0
# urls.explorer                       0
# urls.reddit                         0
# urls.technical_doc                  0
# urls.source_code                    0
# urls.announcement                   0
# platform.id                         5
# platform.name                       5
# platform.slug                       5
# platform.symbol                     5
# platform.token_address              5
# dtype: int64

# %%
# saving a final csv file
df.to_csv('API-data/cryptocurrency_metada.csv', sep= ';', index= False)

# %% [markdown]
# ### 2) Cryptocurrency CoinMarketCap Map
# - Updated only as needed every 30s
#   (se mudar/entrar alguma coisa, atualiza; senão não)

# %%
map_url= base_url+'/v1/cryptocurrency/map'

# 'symbol': 'BTC,ETH,USDT,USDC,BNB,XRP,ADA,BUSD,SOL,DOT'
# they strongly don't recommend us do the queries by symbol (because they can be duplicate for different cryptocurrencias and may also change over time for the same crypto)

# so I take the first 1000 crypto's data ordered according api developers rank
parameters={
    'limit': 10,
    'sort': 'cmc_rank'    
}

response= r.get(
    url= map_url,
    params= parameters,
    headers= headers
)

print(response.status_code)
print(response.reason)

if str(response.status_code)[0] != '2':
    print(response.text)
    # e-mail informando

response.json()['status'] # logs
# Out:
# 200
# OK
# {'timestamp': '2025-01-02T21:41:40.771Z',
#  'error_code': 0,
#  'error_message': None,
#  'elapsed': 61,
#  'credit_count': 1,
#  'notice': None}

# %%
pd.json_normalize(response.json()['data']).to_csv('API-data/top10_map_cryptos.csv', sep= ';', index= False)

# %% [markdown]
# #### 3) Cryptocurrency listing
# - Update frequency: every 60s

# %%
listing_url= base_url+'/v1/cryptocurrency/listings/latest'
aux= [] # lista auxiliar para armazenar os dataframes de iteração
#df= pd.DataFrame() # dataframe vazio

i=1
while True:
    
    print(f'Efetuando chamada dos índices {i} até {i+1000}')
    response= r.get(
        url= listing_url,
        headers= headers,
        params= { 'start': i, 'limit': 1000, 'aux': 'cmc_rank'}
    )
    
    print(f'Status Code: {response.status_code}')
    print(f'Log: {response.reason}')
    print(f'Créditos consumidos: {response.json()['status']['credit_count']}')

    # se não tivermos mais nenhum retorno, encerra o loop
    if len(response.json()['data']) == 0:
        break
    
    aux.append(pd.json_normalize(response.json()['data']))
    i+= 1000 # 1000 para contemplar as cryptos já retornadas
    print('-'*30, end='\n\n')
# Out:
# Efetuando chamada dos índices 1 até 1001
# Status Code: 200
# Log: OK
# Créditos consumidos: 5
# ------------------------------
#
# Efetuando chamada dos índices 1001 até 2001
# Status Code: 200
# Log: OK
# Créditos consumidos: 5
# ------------------------------
#
# Efetuando chamada dos índices 2001 até 3001
# Status Code: 200
# Log: OK
# Créditos consumidos: 5
# ------------------------------
#
# Efetuando chamada dos índices 3001 até 4001
# Status Code: 200
# Log: OK
# Créditos consumidos: 5
# ------------------------------
#
# Efetuando chamada dos índices 4001 até 5001
# Status Code: 200
# Log: OK
# Créditos consumidos: 5
# ------------------------------
#
# Efetuando chamada dos índices 5001 até 6001
# Status Code: 200
# Log: OK
# Créditos consumidos: 5
# ------------------------------
#
# Efetuando chamada dos índices 6001 até 7001
# Status Code: 200
# Log: OK
# Créditos consumidos: 5
# ------------------------------
#
# Efetuando chamada dos índices 7001 até 8001
# Status Code: 200
# Log: OK
# Créditos consumidos: 5
# ------------------------------
#
# Efetuando chamada dos índices 8001 até 9001
# Status Code: 200
# Log: OK
# Créditos consumidos: 5
# ------------------------------
#
# Efetuando chamada dos índices 9001 até 10001
# Status Code: 200
# Log: OK
# Créditos consumidos: 5
# ------------------------------
#
# Efetuando chamada dos índices 10001 até 11001
# Status Code: 200
# Log: OK
# Créditos consumidos: 3
# ------------------------------
#
# Efetuando chamada dos índices 11001 até 12001
# Status Code: 200
# Log: OK
# Créditos consumidos: 0

# %%
df= pd.concat(aux)
df.head()
# Out:
# C:\Users\LUCAS\AppData\Local\Temp\ipykernel_1220\901218407.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df= pd.concat(aux)
#      id         name symbol      slug  infinite_supply  cmc_rank  \
# 0     1      Bitcoin    BTC   bitcoin            False         1
# 1  1027     Ethereum    ETH  ethereum             True         2
# 2   825  Tether USDt   USDT    tether             True         3
# 3    52          XRP    XRP       xrp            False         4
# 4  1839          BNB    BNB       bnb            False         5
#
#    self_reported_circulating_supply  self_reported_market_cap  tvl_ratio  \
# 0                               NaN                       NaN        NaN
# 1                               NaN                       NaN        NaN
# 2                               NaN                       NaN        NaN
# 3                               NaN                       NaN        NaN
# 4                               NaN                       NaN        NaN
#
#                last_updated  ...  quote.USD.percent_change_24h  \
# 0  2025-01-02T21:34:00.000Z  ...                      2.484410
# 1  2025-01-02T21:35:00.000Z  ...                      2.611236
# 2  2025-01-02T21:35:00.000Z  ...                      0.093204
# 3  2025-01-02T21:35:00.000Z  ...                      2.939480
# 4  2025-01-02T21:35:00.000Z  ...                     -0.248000
#
#    quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# 0                     1.423190                      1.074754
# 1                     3.670121                     -4.883505
# 2                    -0.011896                     -0.188113
# 3                    10.462372                    -10.712960
# 4                     2.245785                     -0.472861
#
#    quote.USD.percent_change_60d  quote.USD.percent_change_90d  \
# 0                     40.200864                     55.496827
# 1                     39.546444                     42.096703
# 2                     -0.072570                     -0.132810
# 3                    371.537428                    344.270390
# 4                     26.048530                     26.607997
#
#    quote.USD.market_cap  quote.USD.market_cap_dominance  \
# 0          1.920714e+12                         56.4113
# 1          4.150576e+11                         12.1936
# 2          1.372737e+11                          4.0323
# 3          1.363700e+11                          4.0057
# 4          1.014323e+11                          2.9795
#
#    quote.USD.fully_diluted_market_cap  quote.USD.tvl    quote.USD.last_updated
# 0                        2.036625e+12            NaN  2025-01-02T21:34:00.000Z
# 1                        4.150576e+11            NaN  2025-01-02T21:35:00.000Z
# 2                        1.412766e+11            NaN  2025-01-02T21:35:00.000Z
# 3                        2.375360e+11            NaN  2025-01-02T21:35:00.000Z
# 4                        1.014323e+11            NaN  2025-01-02T21:35:00.000Z
#
# [5 rows x 24 columns]

# %%
df[['id', 'name', 'symbol', 'cmc_rank']].sort_values(by='cmc_rank', ascending= True).head(11).to_csv('API-data/top10_cryptos.csv', sep=';', index=False)

# %%
# defining the full query URL
listing_url= base_url+'/v1/cryptocurrency/listings/latest'

# defining the appropriate parameters (I want to see basic information involving some of the main recent cryptocurrencies)
#'symbol': 'BTC,ETH,USDT,USDC,BNB,XRP,ADA,BUSD,SOL,DOT',
parameters= {
    'limit': 1000,
    'cryptocurrency_type': 'coins'
}
# (bringing top 1000 cryptocurrencies ranked by marketing cap)

# making the call attempt
response= r.get(
    url= listing_url
    ,params= parameters
    ,headers= headers
)

print(response.status_code)
print(response.reason)

# printing the entire response to take a look at the error message if there's a HTTP expection of type 4xx (i.e., user inconsistency)
if str(response.status_code)[0] == '4':
    print(response.json())
# Out:
# 200
# OK

# %%
quotes= pd.json_normalize(response.json()['data'])
quotes.head(n=3)
# Out:
#      id      name symbol      slug  num_market_pairs  \
# 0     1   Bitcoin    BTC   bitcoin             11853
# 1  1027  Ethereum    ETH  ethereum              9773
# 2    52       XRP    XRP       xrp              1491
#
#                  date_added  \
# 0  2010-07-13T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2013-08-04T00:00:00.000Z
#
#                                                 tags    max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1  [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2  [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
#
#    circulating_supply  total_supply  ...  quote.USD.percent_change_24h  \
# 0        1.980477e+07  1.980477e+07  ...                      3.047018
# 1        1.204752e+08  1.204752e+08  ...                      3.328444
# 2        5.741023e+10  9.998674e+10  ...                      3.656093
#
#   quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# 0                    1.517611                      2.135381
# 1                    3.759765                     -3.219741
# 2                   10.410152                     -6.776671
#
#    quote.USD.percent_change_60d  quote.USD.percent_change_90d  \
# 0                     41.916984                     56.120474
# 1                     41.400741                     42.604119
# 2                    377.111049                    346.142798
#
#    quote.USD.market_cap quote.USD.market_cap_dominance  \
# 0          1.928782e+12                        56.5360
# 1          4.172501e+11                        12.2222
# 2          1.372434e+11                         4.0222
#
#    quote.USD.fully_diluted_market_cap  quote.USD.tvl    quote.USD.last_updated
# 0                        2.045185e+12            NaN  2025-01-02T20:03:00.000Z
# 1                        4.172501e+11            NaN  2025-01-02T20:04:00.000Z
# 2                        2.390574e+11            NaN  2025-01-02T20:04:00.000Z
#
# [3 rows x 31 columns]

# %%
quotes.dtypes
# Out:
# id                                      int64
# name                                   object
# symbol                                 object
# slug                                   object
# num_market_pairs                        int64
# date_added                             object
# tags                                   object
# max_supply                            float64
# circulating_supply                    float64
# total_supply                          float64
# infinite_supply                          bool
# platform                               object
# cmc_rank                                int64
# self_reported_circulating_supply      float64
# self_reported_market_cap              float64
# tvl_ratio                             float64
# last_updated                           object
# quote.USD.price                       float64
# quote.USD.volume_24h                  float64
# quote.USD.volume_change_24h           float64
# quote.USD.percent_change_1h           float64
# quote.USD.percent_change_24h          float64
# quote.USD.percent_change_7d           float64
# quote.USD.percent_change_30d          float64
# quote.USD.percent_change_60d          float64
# quote.USD.percent_change_90d          float64
# quote.USD.market_cap                  float64
# quote.USD.market_cap_dominance        float64
# quote.USD.fully_diluted_market_cap    float64
# quote.USD.tvl                         float64
# quote.USD.last_updated                 object
# dtype: object

# %%
# filtering for the cryptos we have interest
quotes= quotes[quotes['symbol'].isin(['BTC','ETH','USDT','USDC','BNB','XRP','ADA','BUSD','SOL','DOT'])]
quotes
# Out:
#       id      name symbol          slug  num_market_pairs  \
# 0      1   Bitcoin    BTC       bitcoin             11853
# 1   1027  Ethereum    ETH      ethereum              9773
# 2     52       XRP    XRP           xrp              1491
# 3   1839       BNB    BNB           bnb              2323
# 4   5426    Solana    SOL        solana               817
# 6   2010   Cardano    ADA       cardano              1425
# 13  6636  Polkadot    DOT  polkadot-new               855
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2013-08-04T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 6   2017-10-01T00:00:00.000Z
# 13  2020-08-19T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 6   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 13  [substrate, polkadot, polkadot-ecosystem, thre...           NaN
#
#     circulating_supply  total_supply  ...  quote.USD.percent_change_24h  \
# 0         1.980477e+07  1.980477e+07  ...                      3.047018
# 1         1.204752e+08  1.204752e+08  ...                      3.328444
# 2         5.741023e+10  9.998674e+10  ...                      3.656093
# 3         1.440069e+08  1.440069e+08  ...                     -0.265576
# 4         4.828132e+08  5.913368e+08  ...                      7.115762
# 6         3.513978e+10  4.499513e+10  ...                      4.378805
# 13        1.534942e+09  1.534942e+09  ...                      2.076861
#
#    quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# 0                     1.517611                      2.135381
# 1                     3.759765                     -3.219741
# 2                    10.410152                     -6.776671
# 3                     1.945406                      2.091914
# 4                     9.396252                     -9.400342
# 6                    11.069639                    -19.186979
# 13                    2.800571                    -25.074203
#
#     quote.USD.percent_change_60d  quote.USD.percent_change_90d  \
# 0                      41.916984                     56.120474
# 1                      41.400741                     42.604119
# 2                     377.111049                    346.142798
# 3                      26.566837                     26.485675
# 4                      28.351905                     43.823042
# 6                     187.463577                    171.874578
# 13                     89.573914                     71.331861
#
#     quote.USD.market_cap quote.USD.market_cap_dominance  \
# 0           1.928782e+12                        56.5360
# 1           4.172501e+11                        12.2222
# 2           1.372434e+11                         4.0222
# 3           1.015120e+11                         2.9750
# 4           9.989180e+10                         2.9261
# 6           3.370696e+10                         0.9874
# 13          1.100204e+10                         0.3223
#
#     quote.USD.fully_diluted_market_cap  quote.USD.tvl  \
# 0                         2.045185e+12            NaN
# 1                         4.172501e+11            NaN
# 2                         2.390574e+11            NaN
# 3                         1.015120e+11            NaN
# 4                         1.223448e+11            NaN
# 6                         4.316513e+10            NaN
# 13                        1.100204e+10            NaN
#
#       quote.USD.last_updated
# 0   2025-01-02T20:03:00.000Z
# 1   2025-01-02T20:04:00.000Z
# 2   2025-01-02T20:04:00.000Z
# 3   2025-01-02T20:04:00.000Z
# 4   2025-01-02T20:04:00.000Z
# 6   2025-01-02T20:04:00.000Z
# 13  2025-01-02T20:04:00.000Z
#
# [7 rows x 31 columns]

# %%
# defining a new dataframe with only the columns we want to perform studies
df= quotes[
    [
        'id', # crypto Id
        'name', # crypto name
        'symbol', # crypto symbol
        'date_added', # date in which it was added to coinmarket cap database
        'last_updated', # last updated date in coinmarket cap database 
        'circulating_supply', # approximate number of coins in circulation 
        'total_supply', # estimative of total number of coins that exist at the moment
        'quote.USD.price', # estimative of the coin price in dollars
        'quote.USD.volume_24h', # total trading volume over last 24h
        'quote.USD.market_cap', # indicates the rank of the cryptocurrency based on its market capitalization
        'quote.USD.percent_change_7d' # percentage change in the trading price over the last 7 day 
    ]
]
# Out:
#       id      name symbol                date_added              last_updated  \
# 0      1   Bitcoin    BTC  2010-07-13T00:00:00.000Z  2025-01-02T20:03:00.000Z
# 1   1027  Ethereum    ETH  2015-08-07T00:00:00.000Z  2025-01-02T20:04:00.000Z
# 2     52       XRP    XRP  2013-08-04T00:00:00.000Z  2025-01-02T20:04:00.000Z
# 3   1839       BNB    BNB  2017-07-25T00:00:00.000Z  2025-01-02T20:04:00.000Z
# 4   5426    Solana    SOL  2020-04-10T00:00:00.000Z  2025-01-02T20:04:00.000Z
# 6   2010   Cardano    ADA  2017-10-01T00:00:00.000Z  2025-01-02T20:04:00.000Z
# 13  6636  Polkadot    DOT  2020-08-19T00:00:00.000Z  2025-01-02T20:04:00.000Z
#
#     circulating_supply  total_supply  quote.USD.price  quote.USD.volume_24h  \
# 0         1.980477e+07  1.980477e+07     97389.753029          4.582249e+10
# 1         1.204752e+08  1.204752e+08      3463.368692          2.242816e+10
# 2         5.741023e+10  9.998674e+10         2.390574          9.143487e+09
# 3         1.440069e+08  1.440069e+08       704.910879          1.884816e+09
# 4         4.828132e+08  5.913368e+08       206.895337          4.289774e+09
# 6         3.513978e+10  4.499513e+10         0.959225          1.367080e+09
# 13        1.534942e+09  1.534942e+09         7.167723          3.152830e+08
#
#     quote.USD.market_cap  quote.USD.percent_change_7d
# 0           1.928782e+12                     1.517611
# 1           4.172501e+11                     3.759765
# 2           1.372434e+11                    10.410152
# 3           1.015120e+11                     1.945406
# 4           9.989180e+10                     9.396252
# 6           3.370696e+10                    11.069639
# 13          1.100204e+10                     2.800571

# %% [markdown]
# ### 3.1) Data Cleaning and Preparing
